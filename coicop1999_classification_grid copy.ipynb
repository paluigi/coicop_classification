# %% [markdown]
# # Structuring COICOP 1999 information for classification

# %% [markdown]
# The COICOPP 1999 classification contains unstructured information for its most detailed level of classification. This notebook leverages LLMs in order to structure this information in a format which can be used for similarity search.

# %%
import os
import time # Add delays because of free API rate limits
from datetime import datetime

import pandas as pd

from typing import List
from pydantic import BaseModel
from pydantic_ai import Agent
from pydantic_ai.models.mistral import MistralModel
from pydantic_ai.models.groq import GroqModel

from dotenv import dotenv_values

# %%
import nest_asyncio # Fix issues with Jupyter notebook event loop
nest_asyncio.apply()

# %% [markdown]
# Import environment variables with API keys

# %%
config = dotenv_values(".env")

# %% [markdown]
# Define the Pydantic model for parsing the additional information in each COICOP 1999 level 3

# %%
class CoicopDetails(BaseModel):
    examples: List[str]

# %% [markdown]
# Read COICOP 1999 definitions (different languages)

# %%
usecols = ["Code","Description","ExplanatoryNote"]
usecols_es = ["Code","Title","ExplanatoryNoteInclusion"] # Spanish has different columns

data_en = pd.read_csv(
    filepath_or_buffer="coicop_1999/coicop1999_en.csv", 
    usecols=usecols,)

data_fr = pd.read_csv(
    filepath_or_buffer="coicop_1999/coicop1999_fr.csv", 
    usecols=usecols,)

data_es = pd.read_csv(
    filepath_or_buffer="coicop_1999/coicop1999_es.csv", 
    usecols=usecols_es,)

# %% [markdown]
# Remove exclusion note from the English and French files, rename Spanish columns.
#
# Remove (ND), (SD), (D), (S) markings from the class names
#
# Filter level 3 classes only for LLMs queries

# %%
def process_classes(df):
    """
    Process DataFrame with the following operations:
    1. Filter rows where Code contains exactly 2 dots
    2. Truncate ExplanatoryNote at either 'Excludes:' or 'Sont exclus'
    3. Remove classification markers from Description
    
    Args:
        df (pd.DataFrame): Input DataFrame with columns Code, Description, and ExplanatoryNote
    
    Returns:
        pd.DataFrame: Processed DataFrame
    """
    # Create a copy to avoid modifying the original
    result_df = df.copy()
    
    # 1. Select rows where Code has exactly 2 dots
    result_df = result_df[result_df['Code'].str.count(r'\.') == 2]
    
    # 2. Process ExplanatoryNote column
    def truncate_at_exclusions(text):
        if pd.isna(text):
            return text
            
        # Check for both patterns
        excludes_split = text.split('Excludes:')
        sont_exclus_split = text.split('Sont exclus')
        
        # If 'Excludes:' is found, use that split
        if len(excludes_split) > 1:
            return excludes_split[0].strip()
        # If 'Sont exclus' is found, use that split
        elif len(sont_exclus_split) > 1:
            return sont_exclus_split[0].strip()
        # If neither pattern is found, return the original text
        return text.strip()
    
    result_df['ExplanatoryNote'] = result_df['ExplanatoryNote'].apply(truncate_at_exclusions)
    
    # 3. Remove classification markers from Description
    markers_pattern = r'\s*\((ND|SD|S|D)\)'
    result_df['Description'] = result_df['Description'].str.replace(markers_pattern, '', regex=True)
    
    return result_df

# %%
level3_en = process_classes(data_en)
level3_fr = process_classes(data_fr)

# %%
data_es["Description"] = data_es["Title"]
data_es["ExplanatoryNote"] = data_es["ExplanatoryNoteInclusion"]

data_es = data_es.drop(columns=["Title", "ExplanatoryNoteInclusion"], axis=1)
level3_es = process_classes(data_es)

# %%
data_df = pd.concat([level3_en, level3_fr, level3_es], ignore_index=True)

# %%
data_dict = data_df.to_dict(orient="records")

# %% [markdown]
# ## Mistral

# %% [markdown]
# Initialize PydanticAI agent to structure information

# %%
llm_model = "mistral-large-latest"

# %%
model = MistralModel(model_name=llm_model, api_key=config.get("MISTRAL_API_KEY"))
agent = Agent(
    model=model,
    retries=3,
    result_type=CoicopDetails,
    system_prompt=(
        'You are an expert data curator. You will receive a string of text '
        'with examples of items to be included into a certain classification. '
        'Your task is to transform this text into a list of self-explainig '
        'items descriptions, exploding the examples to the most granular level you can '
        'identify in the text. '
        'Each item description should contain all necessary information for classification '
        'as provided in the original text. Prefer complete descriptions rather than single words. '
        'If possible, avoid the use of ambiguous or generic terms such as `other` or `miscellaneous`. '
        'Your output should be in the same language as the input text. '
        ),
)

# %% [markdown]
# Run calls to the Agent to extract and format information

# %%
results = []
failed_calls = []
for i, item in enumerate(data_dict):
    # Print every 20 items to show progress
    if i % 20 == 0:
        print(f"Processing item {i+1} out of {len(data_dict)}")
    # Add switch to skip none items
    if item.get("ExplanatoryNote") is None:
        # No information to parse, just append existing item
        results.append(item)
        continue
    # Time delay to respect API rate limits
    time.sleep(3)
    try:
        prompt = "{}. {}".format(item.get("Description"), item.get("ExplanatoryNote"))
        agent_result = agent.run_sync(prompt, model_settings={'temperature': 0.0})
        # Add to results all examples, including the original class name...list concatenation
        for ex in [item.get("Description")] + agent_result.data.model_dump().get("examples"):
            # the new "Description" is inserted at the end, so it overwrites the original one
            results.append({**item, "Description": ex})
    except Exception as e:
        failed_calls.append(item)
        print(f"Error processing item {i+1} out of {len(data_dict)}")
        print(item)
        print(e)
        continue

# %% [markdown]
# Save results and failed calls

# %%
results_df = pd.DataFrame(results)
results_df.drop(columns=["ExplanatoryNote"]).to_csv(
    "results/coicop1999_{}_{}.csv".format(
        llm_model,
        datetime.now().strftime("%Y-%m-%d_%H%M%S")),
    index=False)

# %%
failed_df = pd.DataFrame(failed_calls)
failed_df.to_csv(
    "results/failed_coicop1999_{}_{}.csv".format(
        llm_model,
        datetime.now().strftime("%Y-%m-%d_%H%M%S")),
    index=False)

# %% [markdown]
# ## Llama 3.3 on Groq

# %%
llm_model = "llama-3.3-70b-versatile"

# %%
model = GroqModel(
    model_name=llm_model, 
    api_key=config.get("GROQ_API_KEY"))
agent = Agent(
    model=model,
    retries=3,
    result_type=CoicopDetails,
    system_prompt=(
        'You are an expert data curator. You will receive a string of text '
        'with examples of items to be included into a certain classification. '
        'Your task is to transform this text into a list of self-explainig '
        'items descriptions, exploding the examples to the most granular level you can '
        'identify in the text. '
        'Each item description should contain all necessary information for classification '
        'as provided in the original text. Prefer complete descriptions rather than single words. '
        'If possible, avoid the use of ambiguous or generic terms such as `other` or `miscellaneous`. '
        'Your output should be in the same language as the input text. '
        ),
)

# %%
results = []
failed_calls = []
for i, item in enumerate(data_dict):
    # Print every 20 items to show progress
    if i % 20 == 0:
        print(f"Processing item {i+1} out of {len(data_dict)}")
    # Add switch to skip none items
    if item.get("ExplanatoryNote") is None:
        # No information to parse, just append existing item
        results.append(item)
        continue
    # Time delay to respect API rate limits
    time.sleep(3)
    try:
        prompt = "{}. {}".format(item.get("Description"), item.get("ExplanatoryNote"))
        agent_result = agent.run_sync(prompt, model_settings={'temperature': 0.0})
        # Add to results all examples, including the original class name...list concatenation
        for ex in [item.get("Description")] + agent_result.data.model_dump().get("examples"):
            # the new "Description" is inserted at the end, so it overwrites the original one
            results.append({**item, "Description": ex})
    except Exception as e:
        failed_calls.append(item)
        print(f"Error processing item {i+1} out of {len(data_dict)}")
        print(item)
        print(e)
        continue
# Out:
# Processing item 1 out of 471
# Processing item 21 out of 471
# Processing item 41 out of 471
# Processing item 61 out of 471
# Processing item 81 out of 471
# Processing item 101 out of 471
# Processing item 121 out of 471
# Processing item 141 out of 471
# Processing item 161 out of 471
# Processing item 181 out of 471
# Error processing item 189 out of 471
# {'Code': '04.4.4', 'Description': 'Services divers liés au logement n.c.a.', 'ExplanatoryNote': '- Charges de copropriété (gardiennage, jardinage, nettoyage des escaliers, chauffage et éclairage, entretien des ascenseurs et des vide-ordures, etc.) dans les immeubles collectifs;\r\n- Services relatifs à la sécurité des habitations;\r\n- Déblaiement de la neige et ramonage.'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100229, Requested 246. Please try again in 6m50.635999999s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 190 out of 471
# {'Code': '04.5.1', 'Description': 'Électricité', 'ExplanatoryNote': '- Électricité.\r\nSont inclus : dépenses connexes (location de compteur, relevé de compteur, redevances fixes, etc.).'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100225, Requested 199. Please try again in 6m6.745s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 191 out of 471
# {'Code': '04.5.2', 'Description': 'Gaz', 'ExplanatoryNote': '- Gaz de ville et gaz naturel;\r\n- Hydrocarbures liquéfiés (butane, propane, etc.).\r\nSont inclus : dépenses connexes (location de compteur, relevé de compteur, récipients de stockage, redevances fixes, etc.).'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100221, Requested 220. Please try again in 6m21.712999999s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 192 out of 471
# {'Code': '04.5.3', 'Description': 'Combustibles liquides', 'ExplanatoryNote': "- Fioul domestique (pour le chauffage et l'éclairage)."}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100217, Requested 185. Please try again in 5m48.179s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 193 out of 471
# {'Code': '04.5.4', 'Description': 'Combustibles solides', 'ExplanatoryNote': '- Charbon, coke, boulets et briquettes, bois de feu, charbon de bois, tourbe, etc.'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100214, Requested 192. Please try again in 5m51.010999999s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 194 out of 471
# {'Code': '04.5.5', 'Description': 'Énergie thermique', 'ExplanatoryNote': "- Eau chaude ou vapeur provenant d'une centrale de chauffage urbain.\r\nSont inclus : dépenses connexes (location de compteur, relevé de compteur, redevances fixes, etc.); glace utilisée pour rafraîchir ou réfrigérer."}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100210, Requested 226. Please try again in 6m17.176s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 195 out of 471
# {'Code': '05.1.1', 'Description': "Meubles et articles d'ameublement", 'ExplanatoryNote': "- Lits, canapés, divans, tables, chaises, buffets, commodes et étagères;\r\n- Appareils d'éclairage (plafonniers, lampes et lampadaires, globes, lampes de chevet, etc.);\r\n- Tableaux, sculptures, gravures, tapisseries et autres objets d'art, y compris les reproductions d'oeuvre d'art et autres objets décoratifs;\r\n- Paravents, cloisons mobiles et autres meubles et appareils.\r\nSont inclus : frais de livraison et d'installation, le cas échéant; sommiers, matelas, tatamis; meubles de salle de bains; mobilier pour bébé (berceau, chaise haute, parc, etc.); volets; meubles de camping et de jardin; miroirs, bougeoirs et chandeliers."}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100206, Requested 334. Please try again in 7m47.302s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 196 out of 471
# {'Code': '05.1.2', 'Description': 'Tapis et revêtements de sol divers', 'ExplanatoryNote': '- Tapis, moquette, linoléum et autres revêtements de sol analogues.\r\nSont inclus : pose des revêtements de sol.'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100203, Requested 203. Please try again in 5m50.902999999s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 197 out of 471
# {'Code': '05.1.3', 'Description': "Réparation de meubles, d'articles d'ameublement et de revêtements souples pour le sol", 'ExplanatoryNote': "- Réparation de meubles, d'articles d'ameublement et de revêtements souples pour le sol.\r\nSont inclus : valeur totale du service (c'est-à-dire le coût de la main-d'oeuvre et des fournitures); restauration d'oeuvres d'art, de mobilier ancien et de tapis anciens autres que ceux acquis principalement pour servir de réserve de valeur (formation de capital)."}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100199, Requested 278. Please try again in 6m52.477s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 198 out of 471
# {'Code': '05.2.0', 'Description': 'Articles de ménage en textiles', 'ExplanatoryNote': "- Tissus d'ameublement, tissu pour rideaux, doubles rideaux, stores, rideaux de porte, etc.;\r\n- Literie (futons, oreillers, traversins, hamacs, etc.);\r\n- Linge de lit (draps, taies d'oreiller, couvertures, couvertures de voyage, plaids, duvets, couvre-lits et moustiquaires);\r\n- Linge de table et de toilette (nappes, serviettes de table, serviettes et gants de toilette, etc.);\r\n- Autres articles de ménage en textiles (cabas, sacs à linge, sacs à chaussures, housses pour vêtements et meubles, drapeaux, parasols, etc.);\r\n- Réparation de ces articles.\r\nSont inclus : tissu d'ameublement à la coupe; toile cirée; tapis de salle de bains, nattes et paillassons."}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100195, Requested 341. Please try again in 7m43.748s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 199 out of 471
# {'Code': '05.3.1', 'Description': 'Gros appareils ménagers, électriques ou non', 'ExplanatoryNote': "- Réfrigérateurs, congélateurs et réfrigérateurs-congélateurs;\r\n- Lave-linge, sèche-linge, armoires sèche-linge, lave-vaisselle, machines à repasser;\r\n- Cuisinières, rôtissoires, plaques de cuisson, réchauds, fours et fours à micro-ondes;\r\n- Climatiseurs, humidificateurs, appareils de chauffage, chauffe-eau, ventilateurs et hottes aspirantes;\r\n- Aspirateurs, nettoyeurs à vapeur, shampouineuses et machines à décaper, cirer et polir les parquets;\r\n- Autres gros appareils ménagers (coffres-forts, machines à coudre, machines à tricoter, adoucisseurs d'eau, etc.).\r\nSont inclus : livraison et installation des appareils, le cas échéant."}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100192, Requested 342. Please try again in 7m41.462s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 200 out of 471
# {'Code': '05.3.2', 'Description': 'Petits appareils électroménagers', 'ExplanatoryNote': '- Moulins à café, cafetières électriques, centrifugeuses, ouvre-boîtes, mixeurs, friteuses, grils, couteaux, grille-pain, sorbetières, yaourtières, plaques chauffantes, fers à repasser, bouilloires, ventilateurs mobiles, couvertures électriques, etc.'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100188, Requested 239. Please try again in 6m9.224s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Processing item 201 out of 471
# Error processing item 201 out of 471
# {'Code': '05.3.3', 'Description': "Réparation d'appareils ménagers", 'ExplanatoryNote': "- Réparation d'appareils ménagers.\r\nSont inclus : valeur totale du service (c'est-à-dire le coût de la main-d'oeuvre et des fournitures); frais de crédit-bail et de location de gros appareils électroménagers."}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100184, Requested 228. Please try again in 5m56.542999999s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 202 out of 471
# {'Code': '05.4.0', 'Description': 'Verrerie, vaisselle et ustensiles de ménage', 'ExplanatoryNote': "- Verrerie, cristallerie, céramique et porcelaine utilisées pour la table, la cuisine, la salle de bains, les toilettes, au bureau et pour la décoration;\r\n- Articles de coutellerie, couverts et argenterie;\r\n- Ustensiles de cuisine non électriques, quelle qu'en soit la matière (casseroles, cocottes, autocuiseurs, poêles, moulins à café, presse-purée, hachoirs, chauffe-plats, balances de ménages et autres ustensiles mécaniques analogues);\r\n- Articles ménagers non électriques, quelle qu'en soit la matière, telles que boîtes à pain, à café, à épices, etc.; poubelles, corbeilles à papier, paniers à linge, cassettes et coffres-forts portatifs, porte-serviettes, casiers à bouteille, fers à repasser non électriques et planches; boîtes aux lettres, biberons, bouteilles thermos et glacières;\r\n- Réparation de ces articles."}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100180, Requested 390. Please try again in 8m13.255s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 203 out of 471
# {'Code': '05.5.1', 'Description': 'Gros outillage et matériel', 'ExplanatoryNote': "- Outillage et matériel motorisés (perceuses, scies, ponceuses et taille-haies électriques, tracteurs de jardin, tondeuses à gazon, motoculteurs, tronçonneuses et pompes à eau);\r\n- Réparation de ces articles.\r\nSont inclus : frais de crédit-bail ou de location d'outillage et de matériel de bricolage."}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100177, Requested 250. Please try again in 6m9.143s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 204 out of 471
# {'Code': '05.5.2', 'Description': 'Petit outillage et accessoires divers', 'ExplanatoryNote': "- Outils à main (scies, marteaux, tournevis, clefs, pinces, cisailles, râpes et limes, etc.);\r\n- Outils de jardinage (brouettes, arrosoirs, tuyaux d'arrosage, bêches, pelles, râteaux, fourches, faux, faucilles et sécateurs;\r\n- Échelles et escabeaux;\r\n- Accessoires de porte (gonds, poignées et serrures), accessoires de radiateurs et cheminées, autres articles en métal pour la maison (tringles à rideaux, baguettes pour moquette, crochets, etc.) ou pour le jardin (chaînes, grillage, piquets et autre matériel pour clôtures et bordures);\r\n- Petits accessoires électriques (prises de courant, interrupteurs, fils électriques, ampoules, tubes fluorescents, torches électriques, lampes de poche, piles électriques d'usage courant, sonnettes et alarmes, etc.);\r\n- Réparation de ces articles."}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100173, Requested 377. Please try again in 7m55.593999999s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 205 out of 471
# {'Code': '05.6.1', 'Description': "Biens d'équipement ménager non durables", 'ExplanatoryNote': "- Produits de nettoyage et d'entretien (savons, lessives en poudre ou liquides, poudres à récurer, détergents, eau de Javel, adoucissants, assouplissants, produits à nettoyer les vitres, cires, encaustiques, teintures, déboucheurs, désinfectants, insecticides, fongicides, eau distillée, etc.);\r\n- Articles de nettoyage (balais, brosses, pelles, plumeaux, balais et chiffons à poussière, torchons, serpillières, éponges de ménage, tampons à récurer, paille de fer, peau de chamois, etc.);\r\n- Produits en papier (filtres, nappes et serviettes, essuie-tout, sacs à aspirateurs et vaisselle en carton, etc.), papier d'aluminium et sacs-poubelles en plastique;\r\n- Autres articles de ménage non durables (allumettes, bougies, mèches de lampe, alcool à brûler, pinces à linge, porte-manteaux, épingles, épingles de sûreté, aiguilles à coudre, aiguilles à tricoter, dés à coudre, clous, vis, écrous et boulons, punaises, joints, colle et rubans adhésifs à usage ménager, corde, ficelle, gants en caoutchouc, etc.).\r\nSont inclus : cirages, crèmes et autres articles de nettoyage des chaussures; extincteurs de ménage."}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100169, Requested 462. Please try again in 9m5.834999999s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 206 out of 471
# {'Code': '05.6.2', 'Description': 'Services domestiques et services ménagers', 'ExplanatoryNote': "- Services domestiques fournis par du personnel rémunéré employé à titre privé (majordomes, cuisiniers, bonnes, chauffeurs, jardiniers, gouvernantes, secrétaires, précepteurs, jeunes au pair, etc.);\r\n- Services analogues (dont garde d'enfant et ménage) fournis par des entreprises ou des travailleurs indépendants;\r\n- Services ménagers (nettoyage des vitres, désinfection, fumigation, désinsectisation et dératisation, etc.);\r\n- Nettoyage à sec, blanchissage et teinture de linge de maison, d'articles de ménage en textile et de tapis;\r\n- Location de meubles, d'articles d'ameublement, de tapis, d'appareils ménagers et de linge de maison."}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100166, Requested 341. Please try again in 7m18.123s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 207 out of 471
# {'Code': '06.1.1', 'Description': 'Produits pharmaceutiques', 'ExplanatoryNote': '- Préparations pharmaceutiques, médicaments, spécialités pharmaceutiques, sérums et vaccins, vitamines et oligo-éléments, huile de foie de morue et de flétan, contraceptifs oraux.'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100162, Requested 219. Please try again in 5m29.443s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 208 out of 471
# {'Code': '06.1.2', 'Description': 'Produits médicaux divers', 'ExplanatoryNote': '- Thermomètres médicaux, pansements adhésifs et non adhésifs, seringues hypodermiques, trousses de premier secours, bouillottes et poches de glace, bonneterie médicale (bas à varices, genouillères, etc.), tests de grossesse, préservatifs et autres contraceptifs mécaniques.'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100158, Requested 243. Please try again in 5m46.849s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 209 out of 471
# {'Code': '06.1.3', 'Description': 'Appareils et matériel thérapeutiques', 'ExplanatoryNote': "- Lunettes de vue et lentilles de contact, aides auditives, oeil de verre, membres artificiels et autres prothèses diverses, appareils, bandes, chaussures et ceintures orthopédiques, bandages et supports herniaires, minerves, matériel de massage médical et lampes thérapeutiques, fauteuils roulants et voitures d'invalide motorisés ou non, lits ?spéciaux?, béquilles, appareils électroniques et autres servant à surveiller la tension artérielle, etc.;\r\n- Réparation de ces articles.\r\nSont inclus : prothèses dentaires (mais non les frais de pose)."}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100154, Requested 316. Please try again in 6m46.734999999s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 210 out of 471
# {'Code': '06.2.1', 'Description': 'Services médicaux', 'ExplanatoryNote': "- Consultations de médecins généralistes ou spécialistes.\r\nSont inclus : services d'orthodontiste."}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100151, Requested 196. Please try again in 4m59.869s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 211 out of 471
# {'Code': '06.2.2', 'Description': 'Services dentaires', 'ExplanatoryNote': "- Services de dentistes, spécialistes de l'hygiène buccale et autres auxiliaires dentaires.\r\nSont inclus : frais de pose des prothèses dentaires."}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100147, Requested 208. Please try again in 5m6.957s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 212 out of 471
# {'Code': '06.2.3', 'Description': 'Services paramédicaux', 'ExplanatoryNote': "- Services des laboratoires d'analyses médicales et des centres de radiologie;\r\n- Services d'infirmiers et de sages-femmes indépendants;\r\n- Services d'acupuncteurs, de chiropracteurs et d'ostéopathes, d'optométristes, de physiothérapeutes, d'orthophonistes, etc., indépendants;\r\n- Kinésithérapie;\r\n- Cures thermales ou thalassothérapie ambulatoires (autres que services fournis par les hôpitaux;\r\n- Services d'ambulance (autres que ceux fournis par les hôpitaux);\r\n- Location de matériel thérapeutique.\r\nSont inclus : services des praticiens de la médecine traditionnelle."}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100143, Requested 318. Please try again in 6m38.719s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 213 out of 471
# {'Code': '06.3.0', 'Description': 'Services hospitaliers', 'ExplanatoryNote': "Fourniture des services suivants aux patients hospitalisés :\r\n- Services de base : administration; hébergement, restauration; surveillance et soins assurés par du personnel non spécialisé (aides-soignants); premiers soins et réanimation; transport par ambulance; distribution de médicaments et autres produits pharmaceutiques; fourniture d'appareils et de matériel thérapeutiques;\r\n- Services médicaux : services de médecins généralistes et spécialistes, de chirurgiens et de dentistes; analyses médicales et radiologie; services paramédicaux (services d'infirmiers, de sages-femmes, de chiropracteurs, d'optométristes, de physiothérapeutes, d'orthophonistes, etc.)."}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100139, Requested 342. Please try again in 6m56.277s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 214 out of 471
# {'Code': '07.1.1', 'Description': 'Voitures automobiles', 'ExplanatoryNote': '- Voitures automobiles de tourisme (y compris les breaks, monospaces, etc.) à deux ou quatre roues motrices.'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100136, Requested 198. Please try again in 4m48.612s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 215 out of 471
# {'Code': '07.1.2', 'Description': 'Motocycles', 'ExplanatoryNote': '- Motocycles de tous types, scooters et cyclomoteurs.\r\nSont inclus : side-cars; motoneiges.'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100132, Requested 191. Please try again in 4m39.359999999s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 216 out of 471
# {'Code': '07.1.3', 'Description': 'Bicyclettes', 'ExplanatoryNote': '- Bicyclettes et tricycles en tous genres.\r\nSont inclus : cyclopousses.'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100128, Requested 187. Please try again in 4m32.63s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 217 out of 471
# {'Code': '07.1.4', 'Description': 'Véhicules à traction animale', 'ExplanatoryNote': '- Véhicules à traction animale.\r\nSont inclus : animaux tirant le véhicule et matériel connexe (jougs, colliers, harnais, brides, guides, etc.).'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100124, Requested 210. Please try again in 4m49.217999999s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 218 out of 471
# {'Code': '07.2.1', 'Description': 'Pièces de rechange et accessoires pour véhicules de tourisme', 'ExplanatoryNote': "- Pneus (neufs, d'occasion ou rechapés), chambres à air, bougies d'allumage, amortisseurs, filtres, pompes et autres pièces de rechange ou accessoires pour véhicule particulier.\r\nSont inclus : extincteurs pour véhicules; produits expressément destinés au nettoyage et à l'entretien de véhicules (peintures, produits pour nettoyer les chromes, matériaux d'étanchéité et produits d'entretien de la carrosserie; housses pour voitures, motocycles, etc.)."}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100120, Requested 297. Please try again in 6m1.117s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 219 out of 471
# {'Code': '07.2.2', 'Description': 'Carburants et lubrifiants pour véhicules de tourisme', 'ExplanatoryNote': "- Essence et autres carburants (gazole, gaz de pétrole liquéfié, alcool et mélanges pour moteur à deux temps, etc.);\r\n- Lubrifiants, liquides de frein et d'embrayage, liquides de refroidissement et additifs.\r\nSont inclus : carburant nécessaire au gros outillage et au matériel visés à la rubrique 05.5.1 et aux véhicules de plaisance visés à la rubrique 09.2.1."}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100117, Requested 273. Please try again in 5m37.212999999s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 220 out of 471
# {'Code': '07.2.3', 'Description': 'Entretien et réparation de véhicules particuliers', 'ExplanatoryNote': "- Services liés à l'entretien et à la réparation de véhicules particuliers (pose de pièces de rechange et d'accessoires, équilibrage des roues, inspection technique, dépannage, vidange, graissage et lavage.\r\nSont inclus : valeur totale du service (c'est-à-dire le coût de la main-d'oeuvre et des)."}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100113, Requested 256. Please try again in 5m19.337s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Processing item 221 out of 471
# Error processing item 221 out of 471
# {'Code': '07.2.4', 'Description': 'Services divers liés aux véhicules particuliers', 'ExplanatoryNote': '- Location de garages ou de places de stationnement non liés au logement;\r\n- Péages (ponts, tunnels, bacs, autoroutes) et parcmètres;\r\n- Leçons de conduite, examen du permis de conduire et permis de conduire;\r\n- Contrôle technique automobile;\r\n- Location de voiture sans chauffeur.'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100109, Requested 250. Please try again in 5m10.871999999s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 222 out of 471
# {'Code': '07.3.1', 'Description': 'Transport ferroviaire de passagers', 'ExplanatoryNote': '- Transport de personnes, voyageant seule ou en groupe, et de bagages par train, tramway et métro.\r\nSont inclus : transport de véhicules de tourisme.'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100106, Requested 212. Please try again in 4m34.765999999s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 223 out of 471
# {'Code': '07.3.2', 'Description': 'Transport routier de passagers', 'ExplanatoryNote': '- Transport de personnes, voyageant seule ou en groupe, et de bagages par autobus, autocar, taxi ou voiture de louage avec chauffeur.'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100102, Requested 207. Please try again in 4m27.307s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 224 out of 471
# {'Code': '07.3.3', 'Description': 'Transport aérien de passagers', 'ExplanatoryNote': '- Transport de personnes, voyageant seule ou en groupe, et de bagages par avion ou hélicoptère.'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100098, Requested 198. Please try again in 4m16.329999999s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 225 out of 471
# {'Code': '07.3.4', 'Description': 'Transport maritime et fluvial de passagers', 'ExplanatoryNote': '- Transport de personnes, voyageant seule ou en groupe, et de bagages par navire, bateau, bac, hydroglisseur et hydroptère.\r\nSont inclus : transport de véhicules de tourisme.'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100094, Requested 221. Please try again in 4m32.916s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 226 out of 471
# {'Code': '07.3.5', 'Description': 'Transport combiné de passagers', 'ExplanatoryNote': "- Transport de personnes, voyageant seule ou en groupe, et de bagages par au moins deux modes de transport, lorsqu'il n'est pas possible d'établir la part revenant à chaque mode de transport.\r\nSont inclus : transport de véhicules de tourisme."}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100091, Requested 235. Please try again in 4m41.721s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 227 out of 471
# {'Code': '07.3.6', 'Description': 'Services de transport divers', 'ExplanatoryNote': "- Transport par funiculaire, téléphérique et télésiège;\r\n- Services de déménagement et de garde-meuble; \r\n- Services de porteur, de consigne et d'expédition de bagages;\r\n- Commissions d'agents de voyage, lorsqu'elles sont facturées séparément."}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100087, Requested 237. Please try again in 4m40.208s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 228 out of 471
# {'Code': '08.1.0', 'Description': 'Services postaux', 'ExplanatoryNote': "- Frais d'expédition de lettres, cartes postales et colis;\r\n- Expédition de lettres et colis personnels.\r\nSont inclus : l'achat de timbres postaux non oblitérés, cartes postales et aérogrammes préaffranchis."}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100083, Requested 223. Please try again in 4m24.952s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Processing item 241 out of 471
# Error processing item 258 out of 471
# {'Code': '11.1.2', 'Description': 'Cantines', 'ExplanatoryNote': "- Services de restauration des cantines de chantier, d'entreprise et d'établissement scolaire, universitaire et autre.\r\nSont inclus : les réfectoires universitaires, les mess et les carrés d'officiers."}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 99927, Requested 219. Please try again in 2m5.313s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 259 out of 471
# {'Code': '11.2.0', 'Description': "Services d'hébergement", 'ExplanatoryNote': "- Hôtels, pensions de famille, motels, auberges et chambres d'hôtes;\r\n- Villages et centres de vacances, terrains de camping pour tentes et caravanes, auberges de jeunesse et refuges de montagne;\r\n- Pensionnats, résidences universitaires et autres;\r\n- Transports publics (trains, bateaux, etc.) lorsque la location des lits ou couchettes est facturée à part;\r\n- Foyers pour jeunes travailleurs ou immigrés.\r\nSont inclus : les pourboires, les chasseurs d'hôtel."}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 99923, Requested 289. Please try again in 3m2.657s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 260 out of 471
# {'Code': '12.1.1', 'Description': 'Salons de coiffure et instituts de soins et de beauté', 'ExplanatoryNote': "- Services des salons de coiffure, barbiers, instituts de beauté, manucures, pédicures, bains turcs, saunas, solariums, massages à fins non thérapeutiques, etc.\r\nSont inclus : les soins corporels, l'épilation et les soins analogues."}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 99919, Requested 239. Please try again in 2m16.225s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Processing item 261 out of 471
# Error processing item 261 out of 471
# {'Code': '12.1.2', 'Description': 'Appareils électriques pour soins corporels', 'ExplanatoryNote': "- Rasoirs et tondeuses électriques, sèche-cheveux à main et casques, fers à friser et peignes soufflants, lampes à rayons ultraviolets, vibromasseurs, brosses à dents électriques et autres appareils électriques pour l'hygiène dentaire, etc.;\r\n- Réparation de ces articles."}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 99915, Requested 247. Please try again in 2m19.96s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 262 out of 471
# {'Code': '12.1.3', 'Description': 'Autres appareils, articles et produits pour soins corporels', 'ExplanatoryNote': "- Appareils non électriques : rasoirs, tondeuses, lames de rasoir et de tondeuse, ciseaux, limes à ongles, peignes, blaireaux, brosses à cheveux, brosses à dents, brosses à ongles, épingles à cheveux, bigoudis, pèse-personnes, pèse-bébés, etc.;\r\n- Articles d'hygiène corporelle : savon de toilette, savon médicinal, lait et huile de toilette, savon à barbe, crème et mousse à raser, pâte dentifrice, etc.;\r\n- Produits de beauté : rouge à lèvres, vernis à ongles, produits de maquillage et démaquillants (poudres, pinceaux à poudre, houppettes), laques et lotions capillaires, lotions avant et après-rasage, produits solaires, produits épilatoires, parfums et eaux de toilette, déodorants corporels, produits pour le bain, etc.;\r\n- Autres produits : papier de toilette, mouchoirs et serviettes en papier, serviettes hygiéniques, ouate, coton, cotons de tige, couches pour bébés, éponges de toilette, etc."}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 99912, Requested 414. Please try again in 4m41.06s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 263 out of 471
# {'Code': '12.2.0', 'Description': 'Prostitution', 'ExplanatoryNote': '- Services fournis par les prostitué(e)s et services analogues.'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 99908, Requested 185. Please try again in 1m20.021s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 264 out of 471
# {'Code': '12.3.1', 'Description': 'Articles de bijouterie et horlogerie', 'ExplanatoryNote': '- Pierres et métaux précieux et bijoux en pierres et métaux précieux;\r\n- Bijoux fantaisie, boutons de manchettes et épingles de cravate;\r\n- Horloges, montres, chronomètres, réveils, réveils de voyage;\r\n- Réparation de ces articles.'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 99904, Requested 235. Please try again in 1m59.904s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 265 out of 471
# {'Code': '12.3.2', 'Description': 'Autres effets personnels', 'ExplanatoryNote': '- Bagages et autres articles de voyage pour effets personnels : valises, malles, sacs de voyage, mallettes, sacoches, sacs à main, portefeuilles, porte-monnaie, etc.;\r\n- Articles pour bébés : landaus, poussettes, couffins, relax, lits et sièges auto, porte-bébés frontaux et dorsaux, laisses et harnais, etc.;\r\n- Articles pour fumeurs : pipes, briquets, étuis à cigarettes, coupe-cigares, etc.;\r\n- Articles personnels divers : lunettes de soleil, cannes, parapluies et ombrelles, éventails, porte-clefs, etc.;\r\n- Articles funéraires : cercueils, pierres tombales, urnes funéraires, etc.;\r\n- Réparation de ces articles.\r\nSont inclus : le fluide à briquets; les thermomètres et baromètres muraux.'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 99900, Requested 349. Please try again in 3m35.072s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 266 out of 471
# {'Code': '12.4.0', 'Description': 'Protection sociale', 'ExplanatoryNote': "Cette classe comprend l'accueil avec hébergement, les services d'aide à domicile, les services des centres de jour et les services de réadaptation. Elle recouvre en particulier les montants versés par des ménages à :\r\n- Des maisons de retraite, résidences pour personnes handicapées, centres de réadaptation assurant un séjour et une assistance et non des soins et une rééducation, écoles pour handicapés dont le but principal est d'aider les élèves à surmonter leur infirmité;\r\n- Des services visant à faciliter le maintien à domicile des personnes âgées et des handicapés (services d'aide ménagère, de repas, de garderie et centres de vacances);\r\n- Des nourrices, crèches, garderies et autres établissements d'accueil pour enfants;\r\n- Des services de conseil, d'orientation, d'arbitrage, de placement en famille d'accueil et d'adoption à l'intention des familles."}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 99897, Requested 394. Please try again in 4m10.695999999s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 267 out of 471
# {'Code': '12.5.1', 'Description': 'Assurance-vie', 'ExplanatoryNote': "- Rémunération des services d'assurance-vie, d'assurance décès, d'assurance éducation, etc."}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 99893, Requested 193. Please try again in 1m13.83s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 268 out of 471
# {'Code': '12.5.2', 'Description': 'Assurance habitation', 'ExplanatoryNote': "- Rémunération des services d'assurance versée par les propriétaires-occupants et les locataires pour s'assurer contre les risques que couvrent généralement les polices souscrites par les locataires contre l'incendie, le vol, les dégâts des eaux, etc."}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 99889, Requested 236. Please try again in 1m47.753s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 269 out of 471
# {'Code': '12.5.3', 'Description': 'Assurance maladie', 'ExplanatoryNote': "- Rémunération des services d'assurance maladie et d'assurance accident."}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 99885, Requested 189. Please try again in 1m3.906999999s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 270 out of 471
# {'Code': '12.5.4', 'Description': 'Assurance transports', 'ExplanatoryNote': "- Rémunération des services d'assurance liés à l'utilisation des véhicules de tourisme;\r\n- Rémunération des services d'assurance voyage et d'assurance bagages."}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 99882, Requested 213. Please try again in 1m21.449s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 271 out of 471
# {'Code': '12.5.5', 'Description': 'Autres assurances', 'ExplanatoryNote': "- Rémunération des services d'autres assurances telles que l'assurance responsabilité civile contre les blessures ou les dommages causés aux personnes ou à la propriété de tiers."}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 99878, Requested 217. Please try again in 1m21.652999999s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 272 out of 471
# {'Code': '12.6.1', 'Description': "Coût des services d'intermédiation financière indirectement mesurés", 'ExplanatoryNote': "- Coût des services d'intermédiation financière indirectement mesurés."}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 99874, Requested 202. Please try again in 1m5.356s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 273 out of 471
# {'Code': '12.6.2', 'Description': 'Autres services financiers n.c.a.', 'ExplanatoryNote': "- Frais effectivement facturés par les banques, bureaux de poste, caisses d'épargne, bureaux de change et institutions financières analogues;\r\n- Commissions et rémunération des services des agents de change, conseillers en placement, conseils fiscaux et autres;\r\n- Frais administratifs prélevés par les fonds de pension et institutions analogues."}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 99870, Requested 263. Please try again in 1m54.865999999s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 274 out of 471
# {'Code': '12.7.0', 'Description': 'Autres services n.c.a.', 'ExplanatoryNote': "- Montants versés à des conseillers juridiques, bureaux de placement, etc.;\r\n- Montants versés à des services de pompes funèbres et services analogues;\r\n- Montants versés à des agences immobilières, services de logement, commissaires priseurs, établissements de vente aux enchères et autres établissements de courtage;\r\n- Frais de photocopie et de reprographie;\r\n- Frais d'établissement de certificats de naissance, de mariage et de décès et d'autres documents administratifs;\r\n- Frais de parution d'annonces et publicités dans la presse;\r\n- Montants versés à des graphologues, astrologues, détectives privés, gardes du corps, agences matrimoniales et conseillers matrimoniaux, écrivains publics et détenteurs de concessions diverses (chaises, toilettes, vestiaires, etc.)."}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 99867, Requested 370. Please try again in 3m24.146s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 276 out of 471
# {'Code': '13.2.1', 'Description': 'Produits pharmaceutiques', 'ExplanatoryNote': '- Comme indiqué sous 02.1.1 dans la COPNI. Correspond à (06.1.1) et à (14.2.1).'}
# ...
# Error processing item 444 out of 471
# {'Code': '13.4.2', 'Description': 'Enseñanza secundaria', 'ExplanatoryNote': '- Tal como se especifica en CFISFL, 04.2.0. Corresponde a (10.2.0) y (14.4.2).'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100022, Requested 191. Please try again in 3m4.614999999s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 445 out of 471
# {'Code': '13.4.3', 'Description': 'Enseñanza postsecundaria, no terciaria', 'ExplanatoryNote': '- Tal como se especifica en CFISFL, 04.3.0. Corresponde a (10.3.0) y (14.4.3).'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100019, Requested 195. Please try again in 3m4.926s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 446 out of 471
# {'Code': '13.4.4', 'Description': 'Enseñanza terciaria', 'ExplanatoryNote': '- Tal como se especifica en CFISFL, 04.4.0. Corresponde a (10.4.0) y (14.4.4).'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100015, Requested 191. Please try again in 2m58.343s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 447 out of 471
# {'Code': '13.4.5', 'Description': 'Enseñanza no atribuible a ningún nivel', 'ExplanatoryNote': '- Tal como se especifica en CFISFL, 04.5.0. Corresponde a (10.5.0) y (14.4.5).'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100011, Requested 196. Please try again in 2m59.465999999s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 448 out of 471
# {'Code': '13.4.6', 'Description': 'Otros servicios educativos', 'ExplanatoryNote': '- Tal como se especifica en CFISFL, 04.6.0 y 04.7.0.'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100008, Requested 186. Please try again in 2m47.658s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 449 out of 471
# {'Code': '13.5.0', 'Description': 'Protección social', 'ExplanatoryNote': '- Tal como se especifica en CFISFL, 05.1.0 y 05.2.0. Corresponde a (12.4.0) y (14.5.0).'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100004, Requested 192. Please try again in 2m49.512s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 450 out of 471
# {'Code': '13.6.1', 'Description': 'Religión', 'ExplanatoryNote': '- Tal como se especifica en CFISFL, 06.0.0.'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 100000, Requested 179. Please try again in 2m35.047s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 451 out of 471
# {'Code': '13.6.2', 'Description': 'Partidos políticos, organizaciones laborales y profesionales', 'ExplanatoryNote': '- Tal como se especifica en CFISFL, 07.1.0, 07.2.0 y 07.3.0.'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 99997, Requested 196. Please try again in 2m46.56s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 452 out of 471
# {'Code': '13.6.3', 'Description': 'Protección ambiental', 'ExplanatoryNote': '- Tal como se especifica en CFISFL, 08.1.0 y 08.2.0.'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 99993, Requested 184. Please try again in 2m32.926s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 453 out of 471
# {'Code': '13.6.4', 'Description': 'Servicios n.e.p.', 'ExplanatoryNote': '- Tal como se especifica en CFISFL, 09.1.0 y 09.2.0.'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 99990, Requested 183. Please try again in 2m28.892s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 454 out of 471
# {'Code': '14.1.0', 'Description': 'Vivienda', 'ExplanatoryNote': '- Tal como se especifica en CFISFL, 10.6.0. Corresponde a (04.1.1) y (13.1.0).'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 99986, Requested 188. Please try again in 2m29.961s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 455 out of 471
# {'Code': '14.2.1', 'Description': 'Productos farmacéuticos', 'ExplanatoryNote': '- Tal como se especifica en CFG, 07.1.1. Corresponde a (06.1.1) y a (13.2.1).'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 99982, Requested 191. Please try again in 2m29.349s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 456 out of 471
# {'Code': '14.2.2', 'Description': 'Otros productos médicos', 'ExplanatoryNote': '- Tal como se especifica en CFG, 07.1.2. Corresponde a (06.1.2) y (13.2.2).'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 99979, Requested 191. Please try again in 2m26.165s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 457 out of 471
# {'Code': '14.2.3', 'Description': 'Instrumentos y equipo terapéuticos', 'ExplanatoryNote': '- Tal como se especifica en CFG, 07.1.3. Corresponde a (06.1.3) y (13.2.3).'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 99975, Requested 194. Please try again in 2m25.488s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 458 out of 471
# {'Code': '14.2.4', 'Description': 'Servicios médicos ambulatorios', 'ExplanatoryNote': '- Tal como se especifica en CFG, 07.2.1 y 07.2.2. Corresponde a (06.2.1) y (13.2.4).'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 99971, Requested 195. Please try again in 2m23.203s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 459 out of 471
# {'Code': '14.2.5', 'Description': 'Servicios dentales ambulatorios', 'ExplanatoryNote': '- Tal como se especifica en CFG, 07.2.3. Corresponde a (06.2.2) y (13.2.5).'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 99968, Requested 193. Please try again in 2m18.3s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 460 out of 471
# {'Code': '14.2.6', 'Description': 'Servicios paramédicos ambulatorios', 'ExplanatoryNote': '- Tal como se especifica en CFG, 07.2.4. Corresponde a (06.2.3) y (13.2.6).'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 99964, Requested 194. Please try again in 2m15.958s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Processing item 461 out of 471
# Error processing item 461 out of 471
# {'Code': '14.2.7', 'Description': 'Servicios hospitalarios', 'ExplanatoryNote': '- Tal como se especifica en CFG, 07.3.1, 07.3.2, 07.3.3 y 07.3.4. Corresponde a (06.3.0) y (13.2.6).'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 99960, Requested 197. Please try again in 2m15.242s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 462 out of 471
# {'Code': '14.2.8', 'Description': 'Servicios de salud pública', 'ExplanatoryNote': '- Tal como se especifica en CFG, 07.4.0.'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 99956, Requested 183. Please try again in 1m59.903s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 463 out of 471
# {'Code': '14.3.1', 'Description': 'Servicios recreativos y deportivos', 'ExplanatoryNote': '- Tal como se especifica en CFG, 08.1.0. Corresponde a (09.4.1) y (13.3.1).'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 99953, Requested 193. Please try again in 2m5.286999999s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 464 out of 471
# {'Code': '14.3.2', 'Description': 'Servicios culturales', 'ExplanatoryNote': '- Tal como se especifica en CFG, 08.2.0. Corresponde a (09.4.2) y (13.3.2).'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 99949, Requested 190. Please try again in 1m59.502s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 465 out of 471
# {'Code': '14.4.1', 'Description': 'Enseñanza preescolar y primaria', 'ExplanatoryNote': '- Tal como se especifica en CFG, 09.1.1 y 09.1.2. Corresponde a (10.1.0) y (13.4.1).'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 99945, Requested 195. Please try again in 2m0.547s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 466 out of 471
# {'Code': '14.4.2', 'Description': 'Enseñanza secundaria', 'ExplanatoryNote': '- Tal como se especifica en CFG, 09.2.1 y 09.2.2. Corresponde a (10.2.0) y (13.4.2).'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 99941, Requested 192. Please try again in 1m54.699999999s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 467 out of 471
# {'Code': '14.4.3', 'Description': 'Enseñanza postsecundaria, no terciaria', 'ExplanatoryNote': '- Tal como se especifica en CFG, 09.3.0. Corresponde a (10.3.0) y (13.4.3).'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 99938, Requested 195. Please try again in 1m54.169s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 468 out of 471
# {'Code': '14.4.4', 'Description': 'Enseñanza terciaria', 'ExplanatoryNote': '- Tal como se especifica en CFG, 09.4.1 y 09.4.2. Corresponde a (10.4.0) y (13.4.4).'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 99934, Requested 192. Please try again in 1m48.428999999s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 469 out of 471
# {'Code': '14.4.5', 'Description': 'Enseñanza no atribuible a ningún nivel', 'ExplanatoryNote': '- Tal como se especifica en CFG, 09.5.0. Corresponde a (10.5.0) y (13.4.5).'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 99930, Requested 195. Please try again in 1m47.769s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 470 out of 471
# {'Code': '14.4.6', 'Description': 'Servicios subsidiarios de educación', 'ExplanatoryNote': '- Tal como se especifica en CFG, 09.6.0.'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 99927, Requested 185. Please try again in 1m36.008999999s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# Error processing item 471 out of 471
# {'Code': '14.5.0', 'Description': 'Protección social', 'ExplanatoryNote': '- Tal como se especifica en CFG, 10.1.1 a 10.5.0 y 10.7.0. Corresponde a (12.4.0) y (13.5.0).'}
# Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-versatile` in organization `org_01j35s7c84e52rc99qc1zg7hw0` service tier `on_demand` on : Limit 100000, Used 99923, Requested 194. Please try again in 1m40.662s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}

# %%
results_df = pd.DataFrame(results)
results_df.drop(columns=["ExplanatoryNote"]).to_csv(
    "results/coicop1999_{}_{}.csv".format(
        llm_model,
        datetime.now().strftime("%Y-%m-%d_%H%M%S")),
    index=False)

# %%
failed_df = pd.DataFrame(failed_calls)
failed_df.to_csv(
    "results/failed_coicop1999_{}_{}.csv".format(
        llm_model,
        datetime.now().strftime("%Y-%m-%d_%H%M%S")),
    index=False)

# %% [markdown]
# ## Deepseek on Groq

# %%
llm_model = "deepseek-r1-distill-llama-70b"

# %%
model = GroqModel(
    model_name=llm_model, 
    api_key=config.get("GROQ_API_KEY"))
agent = Agent(
    model=model,
    retries=3,
    result_type=CoicopDetails,
    system_prompt=(
        'You are an expert data curator. You will receive a string of text '
        'with examples of items to be included into a certain classification. '
        'Your task is to transform this text into a list of self-explainig '
        'items descriptions, exploding the examples to the most granular level you can '
        'identify in the text. '
        'Each item description should contain all necessary information for classification '
        'as provided in the original text. Prefer complete descriptions rather than single words. '
        'If possible, avoid the use of ambiguous or generic terms such as `other` or `miscellaneous`. '
        'Your output should be in the same language as the input text. '
        ),
)

# %%
results = []
failed_calls = []
for i, item in enumerate(data_dict):
    # Print every 20 items to show progress
    if i % 20 == 0:
        print(f"Processing item {i+1} out of {len(data_dict)}")
    # Add switch to skip none items
    if item.get("ExplanatoryNote") is None:
        # No information to parse, just append existing item
        results.append(item)
        continue
    # Time delay to respect API rate limits
    time.sleep(3)
    try:
        prompt = "{}. {}".format(item.get("Description"), item.get("ExplanatoryNote"))
        agent_result = agent.run_sync(prompt, model_settings={'temperature': 0.0})
        # Add to results all examples, including the original class name...list concatenation
        for ex in [item.get("Description")] + agent_result.data.model_dump().get("examples"):
            # the new "Description" is inserted at the end, so it overwrites the original one
            results.append({**item, "Description": ex})
    except Exception as e:
        failed_calls.append(item)
        print(f"Error processing item {i+1} out of {len(data_dict)}")
        print(item)
        print(e)
        continue
# Out:
# Processing item 1 out of 471
# Error processing item 2 out of 471
# {'Code': '01.1.2', 'Description': 'Meat', 'ExplanatoryNote': '- Fresh, chilled or frozen meat of:\r\n- bovine animals, swine, sheep and goat;\r\n- horse, mule, donkey, camel and the like;\r\n- poultry (chicken, duck, goose, turkey, guinea fowl);\r\n- hare, rabbit and game (antelope, deer, boar, pheasant, grouse, pigeon, quail, etc.);\r\n- fresh, chilled or frozen edible offal;\r\n- dried, salted or smoked meat and edible offal (sausages, salami, bacon, ham, p�t�, etc.);\r\n- other preserved or processed meat and meat-based preparations (canned meat, meat extracts, meat juices, meat pies, etc.).\r\nIncludes:  meat and edible offal of marine mammals (seals, walruses, whales, etc.) and exotic animals (kangaroo, ostrich, alligator, etc.);  animals and poultry purchased live for consumption as food.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '\n\n<tool_call>{"name":"final_result","arguments":{"examples":{"items":["Fresh, chilled or frozen meat of bovine animals","Fresh, chilled or frozen meat of swine","Fresh, chilled or frozen meat of sheep and goat","Fresh, chilled or frozen meat of horse, mule, donkey, camel and the like","Fresh, chilled or frozen meat of poultry (chicken, duck, goose, turkey, guinea fowl)","Fresh, chilled or frozen meat of hare, rabbit and game (antelope, deer, boar, pheasant, grouse, pigeon, quail, etc.)","Fresh, chilled or frozen edible offal","Dried, salted or smoked meat and edible offal (sausages, salami, bacon, ham, pâté, etc.)","Other preserved or processed meat and meat-based preparations (canned meat, meat extracts, meat juices, meat pies, etc.)","Meat and edible offal of marine mammals (seals, walruses, whales, etc.)","Meat and edible offal of exotic animals (kangaroo, ostrich, alligator, etc.)","Animals and poultry purchased live for consumption as food"]}}</tool_call>'}}
# Error processing item 3 out of 471
# {'Code': '01.1.3', 'Description': 'Fish and seafood', 'ExplanatoryNote': '- Fresh, chilled or frozen fish;\r\n- fresh, chilled or frozen seafood (crustaceans, molluscs and other shellfish, sea snails);\r\n- dried, smoked or salted fish and seafood;\r\n- other preserved or processed fish and seafood and fish and seafood-based preparations (canned fish and seafood, caviar and other hard roes, fish pies, etc.).\r\nIncludes:  land crabs, land snails and frogs;  fish and seafood purchased live for consumption as food.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '\n\n<tool_call>\n{"name":"final_result","arguments":{"examples":{"items":["Fresh, chilled or frozen fish","Fresh, chilled or frozen seafood (crustaceans, molluscs and other shellfish, sea snails)","Dried, smoked or salted fish and seafood","Other preserved or processed fish and seafood and fish and seafood-based preparations (canned fish and seafood, caviar and other hard roes, fish pies, etc.)","Land crabs, land snails and frogs","Fish and seafood purchased live for consumption as food"}}}}\n</tool_call>'}}
# Error processing item 4 out of 471
# {'Code': '01.1.4', 'Description': 'Milk, cheese and eggs', 'ExplanatoryNote': '- Raw milk;  pasteurized or sterilized milk;\r\n- condensed, evaporated or powdered milk;\r\n- yoghurt, cream, milk-based desserts, milk-based beverages and other similar milk-based products;\r\n- cheese and curd;\r\n- eggs and egg products made wholly from eggs.\r\nIncludes:  milk, cream and yoghurt containing sugar, cocoa, fruit or flavourings;  dairy products not based on milk such as soya milk.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool_call>{"id":"call_3ty9","name":"final_result","arguments":{"examples":{"items":["Raw milk","Pasteurized or sterilized milk","Condensed milk","Evaporated milk","Powdered milk","Yoghurt","Cream","Milk-based desserts","Milk-based beverages","Other similar milk-based products","Cheese","Curd","Eggs","Egg products made wholly from eggs","Milk, cream and yoghurt containing sugar, cocoa, fruit or flavourings","Dairy products not based on milk such as soya milk"]}}}<｜tool▁calls▁end｜>'}}
# Error processing item 5 out of 471
# {'Code': '01.1.5', 'Description': 'Oils and fats', 'ExplanatoryNote': '- Butter and butter products (butter oil, ghee, etc.);\r\n- margarine (including "diet" margarine) and other vegetable fats (including peanut butter);\r\n- edible oils (olive oil, corn oil, sunflower-seed oil, cottonseed oil, soybean oil, groundnut oil, walnut oil, etc.);\r\n- edible animal fats (lard, etc.).'}
# Exceeded maximum retries (3) for result validation
# Error processing item 8 out of 471
# {'Code': '01.1.8', 'Description': 'Sugar, jam, honey, chocolate and confectionery', 'ExplanatoryNote': '- Cane or beet sugar, unrefined or refined, powdered, crystallized or in lumps;\r\n- jams, marmalades, compotes, jellies, fruit pur�es and pastes, natural and artificial honey, maple syrup, molasses and parts of plants preserved in sugar;\r\n- chocolate in bars or slabs, chewing gum, sweets, toffees, pastilles and other confectionery products;\r\n- cocoa-based foods and cocoa-based dessert preparations;\r\n- edible ice, ice cream and sorbet.\r\nIncludes:  artificial sugar substitutes.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool_call>{"id":"call_jdzh","name":"final_result","arguments":{"examples":{"items":["Cane sugar, unrefined","Cane sugar, refined","Cane sugar, powdered","Cane sugar, crystallized","Cane sugar, in lumps","Beet sugar, unrefined","Beet sugar, refined","Beet sugar, powdered","Beet sugar, crystallized","Beet sugar, in lumps","Jams","Marmalades","Compotes","Jellies","Fruit purées","Fruit pastes","Natural honey","Artificial honey","Maple syrup","Molasses","Parts of plants preserved in sugar","Chocolate in bars","Chocolate in slabs","Chewing gum","Sweets","Toffees","Pastilles","Other confectionery products","Cocoa-based foods","Cocoa-based dessert preparations","Edible ice","Ice cream","Sorbet","Artificial sugar substitutes"]},"title":"Sugar, jam, honey, chocolate and confectionery"}}<｜tool▁calls▁end｜>'}}
# Error processing item 9 out of 471
# {'Code': '01.1.9', 'Description': 'Food products n.e.c.', 'ExplanatoryNote': "- Salt, spices (pepper, pimento, ginger, etc.), culinary herbs (parsley, rosemary, thyme, etc.), sauces, condiments, seasonings (mustard, mayonnaise, ketchup, soy sauce, etc.), vinegar;\r\n- prepared baking powders, baker's yeast, dessert preparations, soups, broths, stocks, culinary ingredients, etc.;\r\n- homogenized baby food and dietary preparations irrespective of the composition."}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool_call>{"name":"final_result","arguments":{"examples":{"items":["Salt used for seasoning and food preservation","Pepper, a common spice used to add flavor to various dishes","Pimento, a sweet pepper often used in savory dishes","Ginger, a root used as a spice in baking and cooking","Parsley, a fresh herb used as a garnish or seasoning","Rosemary, a fragrant herb used in roasted dishes and marinades","Thyme, a versatile herb used in soups, stews, and sauces","Mustard, a condiment made from ground mustard seeds","Mayonnaise, a creamy condiment used in sandwiches and salads","Ketchup, a sweet and tangy sauce used as a condiment","Soy sauce, a salty liquid condiment used in Asian cuisine","Vinegar, an acidic liquid used in dressings and preservatives","Prepared baking powders, used as leavening agents in baked goods","Baker\'s yeast, a microorganism used to ferment dough in baking","Dessert preparations, pre-made mixes for sweet dishes","Soups, pre-prepared broths or creamy bases for various soups","Broths, clear soups made from meat or vegetables","Stocks, flavorful liquid bases for soups and sauces","Culinary ingredients, various components used in cooking","Homogenized baby food, nutritionally balanced food for infants","Dietary preparations, specialized food products for specific dietary needs"]}}}'}}
# Error processing item 11 out of 471
# {'Code': '01.2.2', 'Description': 'Mineral waters, soft drinks, fruit and vegetable juices', 'ExplanatoryNote': '- Mineral or spring waters;  all drinking water sold in containers;\r\n- soft drinks such as sodas, lemonades and colas;\r\n- fruit and vegetable juices;\r\n- syrups and concentrates for the preparation of beverages.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool_call>{"id":"call_16rf","name":"final_result","arguments":{"examples":{"items":[{"description":"Mineral or spring waters; all drinking water sold in containers"},{"description":"Soft drinks such as sodas, lemonades and colas"},{"description":"Fruit and vegetable juices; 100% juice without added sugar"},{"description":"Syrups and concentrates for the preparation of beverages"}]}}}<｜tool▁calls▁end｜>'}}
# Error processing item 13 out of 471
# {'Code': '02.1.2', 'Description': 'Wine', 'ExplanatoryNote': '- Wine, cider and perry, including sake;\r\n- wine-based aperitifs, fortified wines, champagne and other sparkling wines.'}
# Exceeded maximum retries (3) for result validation
# Error processing item 14 out of 471
# {'Code': '02.1.3', 'Description': 'Beer', 'ExplanatoryNote': '- All kinds of beer such as ale, lager and porter.\r\nIncludes:  low-alcoholic beer and non-alcoholic beer;  shandy.'}
# Exceeded maximum retries (3) for result validation
# Error processing item 16 out of 471
# {'Code': '02.3.0', 'Description': 'Narcotics', 'ExplanatoryNote': '- Marijuana, opium, cocaine and their derivatives;\r\n- other vegetable-based narcotics such as cola nuts, betel leaves and betel nuts;\r\n- other narcotics including chemicals and man-made drugs.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool_call>{"id":"call_igka","name":"final_result","arguments":{"examples":["Marijuana","Opium","Cocaine and their derivatives","Cola nuts","Betel leaves","Betel nuts","Chemicals","Man-made drugs"]}}<｜tool▁calls▁end｜>'}}
# Error processing item 17 out of 471
# {'Code': '03.1.1', 'Description': 'Clothing materials', 'ExplanatoryNote': '- Clothing materials of natural fibres, of man-made fibres and of their mixtures.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool_call>{"id":"call_c5m2","name":"final_result","arguments":{"examples":["Clothing materials of natural fibres","Clothing materials of man-made fibres","Clothing materials of mixtures of natural and man-made fibres"]}}<｜tool▁calls▁end｜>'}}
# Error processing item 20 out of 471
# {'Code': '03.1.4', 'Description': 'Cleaning, repair and hire of clothing', 'ExplanatoryNote': '- Dry-cleaning, laundering and dyeing of garments;\r\n- darning, mending, repair and altering of garments;\r\n- hire of garments.\r\nIncludes:  total value of the repair service (that is, both the cost of labour and the cost of materials are covered).'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool_call>{"name":"final_result","arguments":{"examples":{"items":["Dry-cleaning of garments","Laundering of garments","Dyeing of garments","Darning of garments","Mending of garments","Repair of garments","Altering of garments","Hire of garments","Total value of repair service (including labor and materials)"}}}</tool_call>'}}
# Processing item 21 out of 471
# Error processing item 22 out of 471
# {'Code': '03.2.2', 'Description': 'Repair and hire of footwear', 'ExplanatoryNote': '- Repair of footwear;  shoe-cleaning services;\r\n- hire of footwear.\r\nIncludes:  total value of the repair service (that is, both the cost of labour and the cost of materials are covered).'}
# Exceeded maximum retries (3) for result validation
# Error processing item 24 out of 471
# {'Code': '04.1.2', 'Description': 'Other actual rentals', 'ExplanatoryNote': '- Rentals actually paid for secondary residences.'}
# Exceeded maximum retries (3) for result validation
# Error processing item 26 out of 471
# {'Code': '04.2.2', 'Description': 'Other imputed rentals', 'ExplanatoryNote': '- Imputed rentals for secondary residences;\r\n- imputed rentals of households paying a reduced rental or housed free.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool_call>{"name":"final_result","arguments":{"examples":{"items":["Imputed rentals for secondary residences","Imputed rentals of households paying a reduced rental or housed free"]},"title":"Other imputed rentals"}}<｜tool▁calls▁end｜>'}}
# Error processing item 27 out of 471
# {'Code': '04.3.1', 'Description': 'Materials for the maintenance and repair of the dwelling', 'ExplanatoryNote': '- Products and materials, such as paints and varnishes, renderings, wallpapers, fabric wall coverings, window panes, plaster, cement, putty, wallpaper pastes, etc., purchased for minor maintenance and repair of the dwelling.\r\nIncludes:  small plumbing items (pipes, taps, joints, etc.), surfacing materials (floorboards, ceramic tiles, etc.) and brushes and scrapers for paint, varnish and wallpaper.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': ''}}
# Error processing item 28 out of 471
# {'Code': '04.3.2', 'Description': 'Services for the maintenance and repair of the dwelling', 'ExplanatoryNote': '- Services of plumbers, electricians, carpenters, glaziers, painters, decorators, floor polishers, etc. engaged for minor maintenance and repair of the dwelling.\r\nIncludes:  total value of the service (that is, both the cost of labour and the cost of materials are covered).'}
# Exceeded maximum retries (3) for result validation
# Error processing item 30 out of 471
# {'Code': '04.4.2', 'Description': 'Refuse collection', 'ExplanatoryNote': '- Refuse collection and disposal.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '\n\n<tool_call>{"id":"call_c5tf","name":"final_result","arguments":{"examples":{"items":["Refuse collection","Refuse collection and disposal"]}}}<｜tool▁calls▁end｜>'}}
# Error processing item 31 out of 471
# {'Code': '04.4.3', 'Description': 'Sewage collection', 'ExplanatoryNote': '- Sewage collection and disposal.'}
# Exceeded maximum retries (3) for result validation
# Error processing item 33 out of 471
# {'Code': '04.5.1', 'Description': 'Electricity', 'ExplanatoryNote': '- Electricity.\r\nIncludes:  associated expenditure such as hire of meters, reading of meters, standing charges, etc.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool_call>{"id":"call_abc1","name":"final_result","arguments":{"properties":{"examples":{"items":["Electricity","Hire of meters","Reading of meters","Standing charges"],"type":"array"}}}}<｜tool▁calls▁end｜>'}}
# Error processing item 34 out of 471
# {'Code': '04.5.2', 'Description': 'Gas', 'ExplanatoryNote': '- Town gas and natural gas;\r\n- liquefied hydrocarbons (butane, propane, etc.).\r\nIncludes:  associated expenditure such as hire of meters, reading of meters, storage containers, standing charges, etc.'}
# Exceeded maximum retries (3) for result validation
# Error processing item 38 out of 471
# {'Code': '05.1.1', 'Description': 'Furniture and furnishings', 'ExplanatoryNote': '- Beds, sofas, couches, tables, chairs, cupboards, chests of drawers and bookshelves;\r\n- lighting equipment such as ceiling lights, standard lamps, globe lights and bedside lamps;\r\n- pictures, sculptures, engravings, tapestries and other art objects including reproductions of works of art and other ornaments;\r\n- screens, folding partitions and other furniture and fixtures.\r\nIncludes:  delivery and installation when applicable;  base mattresses, mattresses, tatamis;  bathroom cabinets;  baby furniture such as cradles, high chairs and playpens;  blinds;  camping and garden furniture;  mirrors, candleholders and candlesticks.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': ''}}
# Error processing item 39 out of 471
# {'Code': '05.1.2', 'Description': 'Carpets and other floor coverings', 'ExplanatoryNote': '- Loose carpets, fitted carpets, linoleum and other such floor coverings.\r\nIncludes:  laying of floor coverings.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': ''}}
# Error processing item 40 out of 471
# {'Code': '05.1.3', 'Description': 'Repair of furniture, furnishings and floor coverings', 'ExplanatoryNote': '- Repair of furniture, furnishings and floor coverings.\r\nIncludes:  total value of the service (that is, both the cost of labour and the cost of materials are covered);  restoration of works of art, antique furniture and antique floor coverings other than those acquired primarily as stores of value (capital formation).'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool_call>{"id":"call_9qez","name":"final_result","arguments":{"examples":{"items":["Repair of furniture, including labor and materials","Repair of furnishings, including labor and materials","Repair of floor coverings, including labor and materials","Restoration of works of art, excluding those acquired primarily as stores of value","Restoration of antique furniture, excluding those acquired primarily as stores of value","Restoration of antique floor coverings, excluding those acquired primarily as stores of value"],"type":"array"}}}<｜tool▁calls▁end｜>'}}
# Processing item 41 out of 471
# Error processing item 41 out of 471
# {'Code': '05.2.0', 'Description': 'Household textiles', 'ExplanatoryNote': '- Furnishing fabrics, curtain material, curtains, double curtains, awnings, door curtains and fabric blinds;\r\n- bedding such as futons, pillows, bolsters and hammocks;\r\n- bedlinen such as sheets, pillowcases, blankets, travelling rugs, plaids, eiderdowns, counterpanes and mosquito nets;\r\n- table linen and bathroom linen such as tablecloths, table napkins, towels and face cloths;\r\n- other household textiles such as shopping bags, laundry bags, shoe bags, covers for clothes and furniture, flags, sunshades, etc.;\r\n- repair of such articles.\r\nIncludes:  cloth bought by the piece;  oilcloth;  bathroom mats, rush mats and doormats.'}
# Exceeded maximum retries (3) for result validation
# Error processing item 42 out of 471
# {'Code': '05.3.1', 'Description': 'Major household appliances whether electric or not', 'ExplanatoryNote': '- Refrigerators, freezers and fridge-freezers;\r\n- washing machines, dryers, drying cabinets, dishwashers, ironing and pressing machines;\r\n- cookers, spit roasters, hobs, ranges, ovens and microwave ovens;\r\n- air-conditioners, humidifiers, space heaters, water heaters, ventilators and extractor hoods;\r\n- vacuum cleaners, steam-cleaning machines, carpet shampooing machines and machines for scrubbing, waxing and polishing floors;\r\n- other major household appliances such as safes, sewing machines, knitting machines, water softeners, etc.\r\nIncludes:  delivery and installation of the appliances when applicable.'}
# Exceeded maximum retries (3) for result validation
# Error processing item 43 out of 471
# {'Code': '05.3.2', 'Description': 'Small electric household appliances', 'ExplanatoryNote': '- Coffee mills, coffee-makers, juice extractors, can-openers, food mixers, deep fryers, meat grills, knives, toasters, ice cream makers, sorbet makers, yoghurt makers, hotplates, irons, kettles, fans, electric blankets, etc.'}
# Exceeded maximum retries (3) for result validation
# Error processing item 44 out of 471
# {'Code': '05.3.3', 'Description': 'Repair of household appliances', 'ExplanatoryNote': '- Repair of household appliances.\r\nIncludes:  total value of the service (that is, both the cost of labour and the cost of materials are covered);  charges for the leasing or rental of major household appliances.'}
# Exceeded maximum retries (3) for result validation
# Error processing item 46 out of 471
# {'Code': '05.5.1', 'Description': 'Major tools and equipment', 'ExplanatoryNote': '- Motorized tools and equipment such as electric drills, saws, sanders and hedge cutters, garden tractors, lawnmowers, cultivators, chainsaws and water pumps;\r\n- repair of such articles.\r\nIncludes:  charges for the leasing or rental of do-it-yourself machinery and equipment.'}
# Exceeded maximum retries (3) for result validation
# Error processing item 48 out of 471
# {'Code': '05.6.1', 'Description': 'Non-durable household goods', 'ExplanatoryNote': '- Cleaning and maintenance products such as soaps, washing powders, washing liquids, scouring powders, detergents, disinfectant bleaches, softeners, conditioners, window-cleaning products, waxes, polishes, dyes, unblocking agents, disinfectants, insecticides, pesticides, fungicides and distilled water;\r\n- articles for cleaning such as brooms, scrubbing brushes, dustpans and dust brushes, dusters, tea towels, floorcloths, household sponges, scourers, steel wool and chamois leathers;\r\n- paper products such as filters, tablecloths and table napkins, kitchen paper, vacuum cleaner bags and cardboard tableware, including aluminium foil and plastic bin liners;\r\n- other non-durable household articles such as matches, candles, lamp wicks, methylated spirits, clothes-pegs, clothes hangers, pins, safety pins, sewing needles, knitting needles, thimbles, nails, screws, nuts and bolts, tacks, washers, glues and adhesive tapes for household use, string, twine and rubber gloves.\r\nIncludes:  polishes, creams and other shoe-cleaning articles;  fire extinguishers for households.'}
# Exceeded maximum retries (3) for result validation
# Error processing item 49 out of 471
# {'Code': '05.6.2', 'Description': 'Domestic services and household services', 'ExplanatoryNote': '- Domestic services supplied by paid staff employed in private service such as butlers, cooks, maids, drivers, gardeners, governesses, secretaries, tutors and au pairs;\r\n- similar services, including babysitting and housework, supplied by enterprises or self-employed persons;\r\n- household services such as window cleaning, disinfecting, fumigation and pest extermination;\r\n- dry-cleaning, laundering and dyeing of household linen, household textiles and carpets;\r\n- hire of furniture, furnishings, carpets, household equipment and household linen.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '\n\n<tool_call>{"name":"final_result","arguments":{"examples":{"items":["Domestic services supplied by paid staff in private service (e.g., butlers, cooks, maids, drivers, gardeners, governesses, secretaries, tutors, au pairs)","Similar services including babysitting and housework by enterprises or self-employed persons","Household services such as window cleaning, disinfecting, fumigation, and pest extermination","Dry-cleaning, laundry, and dyeing of household linen, textiles, and carpets","Hire of furniture, furnishings, carpets, household equipment, and household linen"]}}</tool_call>'}}
# Error processing item 50 out of 471
# {'Code': '06.1.1', 'Description': 'Pharmaceutical products', 'ExplanatoryNote': '- Medicinal preparations, medicinal drugs, patent medicines, serums and vaccines, vitamins and minerals, cod liver oil and halibut liver oil, oral contraceptives.'}
# Exceeded maximum retries (3) for result validation
# Error processing item 52 out of 471
# {'Code': '06.1.3', 'Description': 'Therapeutic appliances and equipment', 'ExplanatoryNote': '- Corrective eyeglasses and contact lenses, hearing aids, glass eyes, artificial limbs and other prosthetic devices, orthopaedic braces and supports, orthopaedic footwear, surgical belts, trusses and supports, neck braces, medical massage equipment and health lamps, powered and unpowered wheelchairs and invalid carriages, "special" beds, crutches, electronic and other devices for monitoring blood pressure, etc.;\r\n- repair of such articles.\r\nIncludes:  dentures but not fitting costs.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool_call>{"name":"final_result","arguments":{"examples":{"items":["Corrective eyeglasses","Contact lenses","Hearing aids","Glass eyes (artificial)","Artificial limbs","Prosthetic devices","Orthopaedic braces","Orthopaedic supports","Orthopaedic footwear","Surgical belts","Trusses","Neck braces","Medical massage equipment","Health lamps","Powered wheelchairs","Unpowered wheelchairs","Invalid carriages","Specialized beds","Crutches","Electronic blood pressure monitors","Other devices for monitoring blood pressure","Dentures (excluding fitting costs)"`]}}}</tool_call>'}}
# Error processing item 54 out of 471
# {'Code': '06.2.2', 'Description': 'Dental services', 'ExplanatoryNote': '- Services of dentists, oral hygienists and other dental auxiliaries.\r\nIncludes:  fitting costs of dentures.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool_call>{"id":"call_ebm2","name":"final_result","arguments":{"examples":{"items":["Dental services","Services of dentists","Services of oral hygienists","Services of other dental auxiliaries","Fitting costs of dentures"]}}}<｜tool▁calls▁end｜>'}}
# Error processing item 56 out of 471
# {'Code': '06.3.0', 'Description': 'Hospital services', 'ExplanatoryNote': '- Hospital services comprise the provision of the following services to hospital in-patients:\r\n- basic services:  administration;  accommodation;  food and drink;  supervision and care by non-specialist staff (nursing auxiliaries);  first aid and resuscitation;  ambulance transport;  provision of medicines and other pharmaceutical products;  provision of therapeutic appliances and equipment;\r\n- medical services:  services of physicians in general or specialist practice, of surgeons and of dentists;  medical analyses and x-rays;  paramedical services such as those of nurses, midwives, chiropractors, optometrists, physiotherapists, speech therapists, etc.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '\n\n<tool_call>\n{"name":"final_result","arguments":{"examples":{"items":["Hospital services: administration","Hospital services: accommodation","Hospital services: food and drink","Hospital services: supervision and care by non-specialist staff (nursing auxiliaries)","Hospital services: first aid and resuscitation","Hospital services: ambulance transport","Hospital services: provision of medicines and other pharmaceutical products","Hospital services: provision of therapeutic appliances and equipment","Hospital services: services of physicians in general or specialist practice, of surgeons and of dentists","Hospital services: medical analyses and x-rays","Hospital services: paramedical services such as those of nurses, midwives, chiropractors, optometrists, physiotherapists, speech therapists, etc."]}}\n</tool_call>'}}
# Error processing item 57 out of 471
# {'Code': '07.1.1', 'Description': 'Motor cars', 'ExplanatoryNote': '- Motor cars, passenger vans, station wagons, estate cars and the like with either two-wheel drive or four-wheel drive.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': 'It seems there\'s a recurring issue with the format of the `examples` parameter. Let me help fix it properly this time. Here\'s the correct tool call with the examples properly formatted as an array:\n\n<tool_call>{"id":"call_jqz2","name":"final_result","arguments":{"examples":{"items":["Motor cars","passenger vans","station wagons","estate cars","two-wheel drive","four-wheel drive"]}}}<｜tool▁calls▁end｜>'}}
# Error processing item 58 out of 471
# {'Code': '07.1.2', 'Description': 'Motor cycles', 'ExplanatoryNote': '- Motor cycles of all types, scooters and powered bicycles.\r\nIncludes:  sidecars;  snowmobiles.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool_call>{"id":"call_3yz9","name":"final_result","arguments":{"examples":["Motor cycles of all types","Scooters","Powered bicycles","Sidecars","Snowmobiles"],"title":"Motor cycles. - Motor cycles of all types, scooters and powered bicycles. Includes: sidecars; snowmobiles."}}<｜tool▁calls▁end｜>'}}
# Error processing item 59 out of 471
# {'Code': '07.1.3', 'Description': 'Bicycles', 'ExplanatoryNote': '- Bicycles and tricycles of all types.\r\nIncludes:  rickshaws.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool_call>{"name":"final_result","arguments":{"examples":{"items":["Bicycles (2-wheel vehicles)","Tricycles (3-wheel vehicles)","Rickshaws (3-wheel passenger vehicles)"}}}</tool_call>'}}
# Error processing item 60 out of 471
# {'Code': '07.1.4', 'Description': 'Animal drawn vehicles', 'ExplanatoryNote': '- Animal drawn vehicles.\r\nIncludes:  animals required to draw the vehicles and related equipment (yokes, collars, harnesses, bridles, reins, etc.).'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '\n\n<tool_call>{"id":"call_9k6","name":"final_result","arguments":{"examples":{"items":["Animal drawn vehicles"],"title":"Examples"}}}<｜tool▁calls▁end｜>'}}
# Processing item 61 out of 471
# Error processing item 61 out of 471
# {'Code': '07.2.1', 'Description': 'Spare parts and accessories for personal transport equipment', 'ExplanatoryNote': '- Tyres (new, used or retreaded), inner tubes, spark plugs, batteries, shock absorbers, filters, pumps and other spare parts or accessories for personal transport equipment.\r\nIncludes:  fire extinguishers for transport equipment;  products specifically for the cleaning and maintenance of transport equipment such as paints, chrome cleaners, sealing compounds and bodywork polishes;  covers for motor cars, motorcycles, etc.'}
# Exceeded maximum retries (3) for result validation
# Error processing item 62 out of 471
# {'Code': '07.2.2', 'Description': 'Fuels and lubricants for personal transport equipment', 'ExplanatoryNote': '- Petrol and other fuels such as diesel, liquid petroleum gas, alcohol and two-stroke mixtures;\r\n- lubricants, brake and transmission fluids, coolants and additives.\r\nIncludes:  fuel for major tools and equipment covered under (05.5.1) and recreational vehicles covered under (09.2.1).'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool_call>{"id":"call_pmx2","name":"final_result","arguments":{"examples":{"items":["Fuels and lubricants for personal transport equipment","Petrol and other fuels such as diesel, liquid petroleum gas, alcohol and two-stroke mixtures","Lubricants, brake and transmission fluids, coolants and additives","Fuel for major tools and equipment covered under (05.5.1)","Fuel for recreational vehicles covered under (09.2.1)"]}}}<｜tool▁calls▁end｜>'}}
# Error processing item 63 out of 471
# {'Code': '07.2.3', 'Description': 'Maintenance and repair of personal transport equipment', 'ExplanatoryNote': '- Services purchased for the maintenance and repair of personal transport equipment such as fitting of parts and accessories, wheel balancing, technical inspection, breakdown services, oil changes, greasing and washing.\r\nIncludes:  total value of the service (that is both the cost of labour and the cost of materials are covered).'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool_call>{"id":"call_3fym","name":"final_result","arguments":{"examples":["Fitting of parts and accessories for personal transport equipment, including both labor and material costs.","Wheel balancing services for personal transport equipment, including labor and materials.","Technical inspection services for personal transport equipment, covering both labor and material expenses.","Breakdown services for personal transport equipment, including labor and materials.","Oil change services for personal transport equipment, including labor and materials.","Greasing services for personal transport equipment, including labor and materials.","Washing services for personal transport equipment, including labor and materials."]}}<｜tool▁calls▁end｜>'}}
# Error processing item 64 out of 471
# {'Code': '07.2.4', 'Description': 'Other services in respect of personal transport equipment', 'ExplanatoryNote': '- Hire of garages or parking spaces not providing parking in connection with the dwelling;\r\n- toll facilities (bridges, tunnels, shuttle ferries, motorways) and parking meters;\r\n- driving lessons, driving tests and driving licences;\r\n- roadworthiness tests;\r\n- hire of personal transport equipment without drivers.'}
# Exceeded maximum retries (3) for result validation
# Error processing item 65 out of 471
# {'Code': '07.3.1', 'Description': 'Passenger transport by railway', 'ExplanatoryNote': '- Transport of individuals and groups of persons and luggage by train, tram and underground.\r\nIncludes:  transport of private vehicles.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': ''}}
# Error processing item 66 out of 471
# {'Code': '07.3.2', 'Description': 'Passenger transport by road', 'ExplanatoryNote': '- Transport of individuals and groups of persons and luggage by bus, coach, taxi and hired car with driver.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool_call>{"id":"call_3mpx","name":"final_result","arguments":{"examples":{"items":["Bus transport: Urban and interurban bus services for passengers.","Coach transport: Intercity and tour coach services for passengers.","Taxi transport: Hailing or booking taxi services for passengers.","Hired car with driver: Chauffeur-driven car services for passengers."]},"title":"Passenger Transport by Road"}}<｜tool▁calls▓end｜>'}}
# Error processing item 67 out of 471
# {'Code': '07.3.3', 'Description': 'Passenger transport by air', 'ExplanatoryNote': '- Transport of individuals and groups of persons and luggage by aeroplane and helicopter.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool_call>{"id":"call_4r67","name":"final_result","arguments":{"examples":{"items":["Transport of individuals by aeroplane","Transport of groups of persons by aeroplane","Transport of luggage by aeroplane","Transport of individuals by helicopter","Transport of groups of persons by helicopter","Transport of luggage by helicopter"]}}}<｜tool▁calls▁end｜>'}}
# Error processing item 68 out of 471
# {'Code': '07.3.4', 'Description': 'Passenger transport by sea and inland waterway', 'ExplanatoryNote': '- Transport of individuals and groups of persons and luggage by ship, boat, ferry, hovercraft and hydrofoil.\r\nIncludes:  transport of private vehicles.'}
# Exceeded maximum retries (3) for result validation
# Error processing item 69 out of 471
# {'Code': '07.3.5', 'Description': 'Combined passenger transport', 'ExplanatoryNote': '- Transport of individuals and groups of persons and luggage by two or more modes of transport when the expenditure cannot be apportioned between them.\r\nIncludes:  transport of private vehicles.'}
# Exceeded maximum retries (3) for result validation
# Error processing item 70 out of 471
# {'Code': '07.3.6', 'Description': 'Other purchased transport services', 'ExplanatoryNote': "- Funicular, cable-car and chairlift transport;\r\n- removal and storage services;\r\n- services of porters and left-luggage and luggage-forwarding offices;\r\n- travel agents' commissions, if separately priced."}
# Exceeded maximum retries (3) for result validation
# Error processing item 72 out of 471
# {'Code': '08.2.0', 'Description': 'Telephone and telefax equipment', 'ExplanatoryNote': '- Purchases of telephones, radio-telephones, telefax machines, telephone-answering machines and telephone loudspeakers;\r\n- repair of such equipment.'}
# Exceeded maximum retries (3) for result validation
# Error processing item 73 out of 471
# {'Code': '08.3.0', 'Description': 'Telephone and telefax services', 'ExplanatoryNote': '- Installation and subscription costs of personal telephone equipment;\r\n- telephone calls from a private line or from a public line (public telephone box, post office cabin, etc.);  telephone calls from hotels, caf�s, restaurants and the like;\r\n- telegraphy, telex and telefax services;\r\n- information transmission services;  Internet connection services;\r\n- hire of telephones, telefax machines, telephone-answering machines and telephone loudspeakers.\r\nIncludes:  radio-telephony, radio-telegraphy and radiotelex services.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '\n\n<tool_call>{"name":"final_result","arguments":{"examples":{"items":["Installation and subscription costs of personal telephone equipment","Telephone calls from a private line","Telephone calls from a public line (e.g., telephone box, post office cabin)","Telephone calls from hotels, caf\\u00e9s, restaurants, and similar establishments","Telegraphy services","Telex services","Telefax services","Information transmission services","Internet connection services","Hire of telephones","Hire of telefax machines","Hire of telephone-answering machines","Hire of telephone loudspeakers","Radio-telephony services","Radio-telegraphy services","Radiotelex services"]}}</tool_call>'}}
# Error processing item 74 out of 471
# {'Code': '09.1.1', 'Description': 'Equipment for the reception, recording and reproduction of sound and pictures', 'ExplanatoryNote': '- Television sets, video cassette players and recorders, television aerials of all types;\r\n- radio sets, car radios, radio clocks, two-way radios, amateur radio receivers and transmitters;\r\n- gramophones, tape players and recorders, cassette players and recorders, CD-players, personal stereos, stereo systems and their constituent units (turntables, tuners, amplifiers, speakers, etc.), microphones and earphones.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool_call>{"id":"call_4yxj","name":"final_result","arguments":{"examples":{"items":["Television sets","Video cassette players and recorders","Television aerials of all types","Radio sets","Car radios","Radio clocks","Two-way radios","Amateur radio receivers and transmitters","Gramophones","Tape players and recorders","Cassette players and recorders","CD-players","Personal stereos","Stereo systems","Turntables","Tuners","Amplifiers","Speakers","Microphones","Earphones"]}}}<｜tool▁calls▁end｜>'}}
# Error processing item 75 out of 471
# {'Code': '09.1.2', 'Description': 'Photographic and cinematographic equipment and optical instruments', 'ExplanatoryNote': '- Still cameras, movie cameras and sound-recording cameras, video cameras and camcorders, film and slide projectors, enlargers and film processing equipment, accessories (screens, viewers, lenses, flash attachments, filters, exposure meters, etc.);\r\n- binoculars, microscopes, telescopes and compasses.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool_call>{"id":"call_snn2","name":"final_result","arguments":{"examples":{"items":"Still cameras, movie cameras, sound-recording cameras, video cameras, camcorders, film projectors, slide projectors, enlargers, film processing equipment, screens, viewers, lenses, flash attachments, filters, exposure meters, binoculars, microscopes, telescopes, compasses"}}}<｜tool▁calls▁end｜>'}}
# Error processing item 77 out of 471
# {'Code': '09.1.4', 'Description': 'Recording media', 'ExplanatoryNote': '- Records and compact discs;\r\n- pre-recorded tapes, cassettes, video cassettes, diskettes and CD-ROMs for tape recorders, cassette recorders, video recorders and personal computers;\r\n- unrecorded tapes, cassettes, video cassettes, diskettes and CD-ROMs for tape recorders, cassette recorders, video recorders and personal computers;\r\n- unexposed films, cartridges and disks for photographic and cinematographic use.\r\nIncludes:  pre-recorded tapes and compact discs of novels, plays, poetry, etc.; pre-recorded diskettes and CD-ROMs containing books, dictionaries, encyclopaedias, foreign language trainers, multimedia presentations, etc. in the form of software;  photographic supplies such as paper and flashbulbs;  unexposed film the price of which includes the cost of processing without separately identifying it.'}
# Exceeded maximum retries (3) for result validation
# Error processing item 78 out of 471
# {'Code': '09.1.5', 'Description': 'Repair of audio-visual, photographic and information processing equipment', 'ExplanatoryNote': '- Repair of audio-visual, photographic and information processing equipment.\r\nIncludes:  total value of the service (that is, both the cost of labour and the cost of materials are covered).'}
# Exceeded maximum retries (3) for result validation
# Error processing item 80 out of 471
# {'Code': '09.2.2', 'Description': 'Musical instruments and major durables for indoor recreation', 'ExplanatoryNote': '- Musical instruments of all sizes, including electronic musical instruments, such as pianos, organs, violins, guitars, drums, trumpets, clarinets, flutes, recorders, harmonicas, etc.;\r\n- billiard tables, ping-pong tables, pinball machines, gaming machines, etc.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool_call>{"id":"call_9gk7","name":"final_result","arguments":{"examples":{"items":["Musical instruments of all sizes, including electronic musical instruments, such as pianos, organs, violins, guitars, drums, trumpets, clarinets, flutes, recorders, harmonicas, etc.","Billiard tables, ping-pong tables, pinball machines, gaming machines, etc."]}}}<｜tool▁calls▁end｜>'}}
# Processing item 81 out of 471
# Error processing item 81 out of 471
# {'Code': '09.2.3', 'Description': 'Maintenance and repair of other major durables for recreation and culture', 'ExplanatoryNote': '- Maintenance and repair of other major durables for recreation and culture.\r\nIncludes:  total value of the service (that is, both the cost of labour and the cost of materials are covered);  laying up for winter of boats, camper vans, caravans, etc.;  hangar services for private planes;  marina services for boats;  veterinary and other services (stabling, feeding, farriery, etc.) for horses and ponies purchased for recreational purposes.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool_call>{"id":"call_4x87","name":"final_result","arguments":{"examples":{"items":["Maintenance and repair of boats for recreation and culture: Includes the total value of the service, laying up for winter of boats, and marina services for boats.","Maintenance and repair of camper vans for recreation and culture: Includes the total value of the service and laying up for winter of camper vans.","Maintenance and repair of caravans for recreation and culture: Includes the total value of the service and laying up for winter of caravans.","Hangar services for private planes: Includes the total value of the service.","Veterinary and other services for horses and ponies purchased for recreational purposes: Includes stabling, feeding, and farriery services."]}}}<｜tool▁calls▁end｜>'}}
# Error processing item 83 out of 471
# ...
# Error processing item 314 out of 471
# {'Code': '14.5.0', 'Description': 'Protection sociale', 'ExplanatoryNote': '- Comme indiqué sous 10.1.1 à 10.5.0 et 10.7.0 dans la COFOG. Correspond à (12.4.0) et (13.5.0).\r\n\r\n=============================='}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': ''}}
# Error processing item 315 out of 471
# {'Code': '01.1.1', 'Description': 'Pan y cereales', 'ExplanatoryNote': '- Arroz de todas clases;\r\n- Maíz, trigo, cebada, avena, centeno y otros cereales en forma de grano, harina fina o harina gruesa;\r\n- Pan y otros productos de panadería (galletas de centeno, galletas duras, pan tostado, bizcochos, galletas de jengibre, barquillos, gofres, panecillos de levadura, bollos, medialunas, pasteles, tartas, tortas, quiches, pizzas, etcétera);\r\n- Mezclas y pastas para la preparación de productos de panadería;\r\n- Pasta de todas las clases, alcuzcuz;\r\n- Preparados de cereal (copos de maíz, copos de avena, etcétera) y otros productos de cereal (malta, harina de malta, extracto de malta, fécula de patata, tapioca, sagú y otros almidones).\r\n\r\nIncluye: productos farináceos preparados con carne, pescado, alimentos marinos, queso, verduras o con fruta.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool_call>{"id":"call_n6mc","name":"final_result","arguments":{"examples":{"items":["Arroz de todas clases","Maíz en forma de grano","Maíz en forma de harina fina","Maíz en forma de harina gruesa","Trigo en forma de grano","Trigo en forma de harina fina","Trigo en forma de harina gruesa","Cebada en forma de grano","Cebada en forma de harina fina","Cebada en forma de harina gruesa","Avena en forma de grano","Avena en forma de harina fina","Avena en forma de harina gruesa","Centeno en forma de grano","Centeno en forma de harina fina","Centeno en forma de harina gruesa","Otros cereales en forma de grano","Otros cereales en forma de harina fina","Otros cereales en forma de harina gruesa","Pan","Galletas de centeno","Galletas duras","Pan tostado","Bizcochos","Galletas de jengibre","Barquillos","Gofres","Panecillos de levadura","Bollos","Medialunas","Pasteles","Tartas","Tortas","Quiches","Pizzas","Mezclas para la preparación de productos de panadería","Pasta de todas las clases","Alcuzcuz","Preparados de cereal (copos de maíz, copos de avena, etcétera)","Otros productos de cereal (malta, harina de malta, extracto de malta, fécula de patata, tapioca, sagú y otros almidones)","Productos farináceos preparados con carne","Productos farináceos preparados con pescado","Productos farináceos preparados con alimentos marinos","Productos farináceos preparados con queso","Productos farináceos preparados con verduras","Productos farináceos preparados con fruta"]}}}<｜tool▁calls▁end｜>'}}
# Error processing item 316 out of 471
# {'Code': '01.1.2', 'Description': 'Carne', 'ExplanatoryNote': '- Carne fresca, refrigerada o congelada de:\r\n- Ganado vacuno, porcino, ovino y caprino;\r\n- Caballo, mula, burro, camello y similares;\r\n- Aves de corral (pollo, pato, ganso, pavo, pintada);\r\n- Liebre, conejo y animales de caza (antílope, ciervo, jabalí, faisán, urogallo, tordo, codorniz, etcétera);\r\n- Desperdicios comestibles frescos, refrigerados o congelados;\r\n- Carnes secas, saladas o ahumadas y desperdicios comestibles (salchichas, embutidos, salame, tocino, jamón, paté, etcétera);\r\n- Otras carnes conservadas o procesadas y preparados de carne (carne envasada, extractos de carne, jugos de carne, tartas de carne, etcétera).\r\n\r\nIncluye: carne y desperdicios comestibles de mamíferos marinos (focas, morsas, ballenas, etcétera) y animales exóticos (canguro, avestruz, caimán, etcétera), animales y aves de corral comprados vivos para su consumo como alimentos.'}
# Exceeded maximum retries (3) for result validation
# Processing item 321 out of 471
# Error processing item 321 out of 471
# {'Code': '01.1.7', 'Description': 'Legumbres-Hortalizas', 'ExplanatoryNote': '- Productos de huerta frescos, refrigerados o congelados que se cultiven por sus hojas y tallos (espárrago, brécol, coliflor, endivia, hinojo, espinaca, etcétera), por su fruto (berenjena, pepino, calabacín, pimiento verde, calabaza, tomate, etcétera), y por su raíz (remolacha, zanahoria, cebolla, chirivía, rábano, nabo, etcétera);\r\n- Patatas y otros tubérculos frescos o refrigerados (yuca, arrurruz, mandioca, batata, etcétera);\r\n- Legumbres y productos a base de legumbres conservados o procesados;\r\n- Productos de tubérculos (harinas finas y harinas gruesas, copos, purés, escamas y hojuelas) con inclusión de preparados congelados como rodajas de patatas.\r\n\r\nIncluye: aceitunas, ajo, leguminosas, maíz dulce, hinojo marino y otras algas comestibles; setas y otros hongos comestibles.'}
# Exceeded maximum retries (3) for result validation
# Error processing item 322 out of 471
# {'Code': '01.1.8', 'Description': 'Azúcar, mermelada, miel, chocolate y dulces de azúcar', 'ExplanatoryNote': '- Azúcar de caña o remolacha sin refinar o refinada, en polvo, cristalizada o en terrones;\r\n- Mermeladas, compotas, jaleas, purés y pastas de frutas, miel natural y artificial, jarabe de arce, melaza y partes de plantas conservadas en azúcar;\r\n- Chocolate en barras o tabletas, goma de mascar, caramelos, toffees, grageas y otros dulces de azúcar;\r\n- Alimentos y preparados para postres a base de cacao;\r\n- Hielo comestible, helados y sorbetes.\r\n\r\nIncluye: sucedáneos artificiales del azúcar.'}
# Exceeded maximum retries (3) for result validation
# Error processing item 323 out of 471
# {'Code': '01.1.9', 'Description': 'Productos alimenticios n.e.p.', 'ExplanatoryNote': '- Sal, especias (pimienta, pimiento, jengibre, etcétera), hierbas culinarias (perejil, romero, tomillo, etcétera), salsas, condimentos, aderezos (mostaza, mayonesa, salsa de tomate, salsa de soja), vinagre;\r\n- Preparados de polvos de hornear, levadura, postres, sopas, caldos, consomés, ingredientes culinarios, etcétera;\r\n- Alimentos para lactantes homogeneizados y preparados dietéticos independientemente de su composición.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '\n\n<tool_call>\n{"name":"final_result","arguments":{"examples":{"items":["Sal","Especias (pimienta, pimiento, jengibre, etc.)","Hierbas culinarias (perejil, romero, tomillo, etc.)","Salsas","Condimentos","Aderezos (mostaza, mayonesa, salsa de tomate, salsa de soja)","Vinagre","Preparados de polvos de hornear","Levadura","Postres","Sopas","Caldos","Consomés","Ingredientes culinarios","Alimentos para lactantes homogeneizados","Preparados dietéticos"}}}}\n</tool_call>'}}
# Error processing item 326 out of 471
# {'Code': '02.1.1', 'Description': 'Bebidas destiladas', 'ExplanatoryNote': '- Aguardientes, licores y otros destilados.\r\n\r\nIncluye: hidromiel, y los aperitivos que no sean a base de vino (02.1.2)'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool_call>{"name":"final_result","arguments":{"examples":{"items":["Bebidas destiladas","Aguardientes","Licores","Otros destilados","Hidromiel","Aperitivos que no sean a base de vino (02.1.2)"}}}</tool_call>'}}
# Error processing item 327 out of 471
# {'Code': '02.1.2', 'Description': 'Vino', 'ExplanatoryNote': '- Vino, sidra y perada, incluido el saké.\r\n- Aperitivos a base de vino, vino fortificado, champán y otros vinos espumosos.'}
# Exceeded maximum retries (3) for result validation
# Error processing item 328 out of 471
# {'Code': '02.1.3', 'Description': 'Cerveza', 'ExplanatoryNote': '- Cerveza de todas clases, como ale, cerveza rubia (lager) y cerveza oscura fuerte (porter)\r\n\r\nIncluye: cerveza de bajo contenido alcohólico y cerveza sin alcohol, cerveza con limonada.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool_call>\n{"name":"final_result","arguments":{"examples":{"items":["Cerveza de todas clases, como ale, cerveza rubia (lager) y cerveza oscura fuerte (porter)","Cerveza de bajo contenido alcohólico","Cerveza sin alcohol","Cerveza con limonada"}}}\n</tool_call>'}}
# Error processing item 330 out of 471
# {'Code': '02.3.0', 'Description': 'Estupefacientes', 'ExplanatoryNote': '- Marihuana, opio, cocaína y sus derivados;\r\n- Otros estupefacientes de origen vegetal, como la nuez de cola, la hoja de betel y la nuez de betel;\r\n- Otros estupefacientes, incluidas las drogas químicas y sintéticas.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '\n\n<tool_call>\n{"name":"final_result","arguments":{"examples":{"items":["Estupefacientes: Marihuana","Estupefacientes: Opio","Estupefacientes: Cocaína y sus derivados","Estupefacientes: Nuez de cola","Estupefacientes: Hoja de betel","Estupefacientes: Nuez de betel","Estupefacientes: Drogas químicas","Estupefacientes: Drogas sintéticas"]}}\n</tool_call>'}}
# Error processing item 331 out of 471
# {'Code': '03.1.1', 'Description': 'Materiales para prendas de vestir', 'ExplanatoryNote': '- Materiales para prendas de vestir hechos de fibras naturales o sintéticas, o de la mezcla de ambas.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool_call>{"id":"call_final","name":"final_result","arguments":{"examples":{"items":["Materiales para prendas de vestir hechas de algodón","Materiales para prendas de vestir hechas de lana","Materiales para prendas de vestir hechas de seda","Materiales para prendas de vestir hechas de lino","Materiales para prendas de vestir hechas de poliéster","Materiales para prendas de vestir hechas de nylon","Materiales para prendas de vestir hechas de acrílico","Materiales para prendas de vestir hechas de elastano","Materiales para prendas de vestir hechas de mezcla de algodón y poliéster","Materiales para prendas de vestir hechas de mezcla de lana y poliéster"]}}}<｜tool▁calls▁end｜>'}}
# Error processing item 333 out of 471
# {'Code': '03.1.3', 'Description': 'Otros artículos y accesorios de vestir', 'ExplanatoryNote': '- Corbatas, pañuelos, bufandas, pañoletas, guantes, manoplas, manguitos, cinturones, tirantes, delantales, vestidos maternales, baberos, salvamangas, sombreros, gorras, boinas, capotes, etcétera.\r\n- Hilos de coser, hilos de punto y accesorios de sastrería como hebillas, botones, broches de presión, cremalleras, cintas, encajes, ribetes, etcétera.\r\n\r\nIncluye: guantes de jardinería y guantes de trabajo, cascos protectores para motociclistas y ciclistas.'}
# Exceeded maximum retries (3) for result validation
# Error processing item 335 out of 471
# {'Code': '03.2.1', 'Description': 'Zapatos y otros calzados', 'ExplanatoryNote': '- Calzado de todas clases para hombres, mujeres, niños (de 3 a 13 años) y lactantes (de 0 a 2 años), incluido el calzado deportivo que pueda utilizarse a diario o para actividades recreativas (calzado para correr, de carreras de fondo, de tenis, de baloncesto, náutico, etcétera).\r\n\r\nIncluye: borceguíes, polainas y artículos análogos; cordones para zapatos; partes del calzado, como tacones, suelas, etcétera, compradas por los hogares para llevar a cabo reparaciones por su cuenta.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool_call>{"id":"call_8uvm","name":"final_result","arguments":{"examples":{"items":["Zapatos y otros calzados","Calzado de todas clases para hombres, mujeres, niños (de 3 a 13 años) y lactantes (de 0 a 2 años)","Calzado deportivo que pueda utilizarse a diario o para actividades recreativas","Calzado para correr","Calzado de carreras de fondo","Calzado de tenis","Calzado de baloncesto","Calzado náutico","Borceguíes","Polainas y artículos análogos","Cordones para zapatos","Partes del calzado, como tacones, suelas, etcétera, compradas por los hogares para llevar a cabo reparaciones por su cuenta"]}}}<｜tool▁calls▁end｜>'}}
# Error processing item 336 out of 471
# {'Code': '03.2.2', 'Description': 'Reparación y alquiler de calzado', 'ExplanatoryNote': '- Reparación de calzado: servicios de limpieza de calzado;\r\n- Alquiler de calzado.\r\n\r\nIncluye: el importe total del servicio de reparación (es decir, tanto el costo de la mano de obra como el de los materiales).'}
# Exceeded maximum retries (3) for result validation
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 16
#      14 try:
#      15     prompt = "{}. {}".format(item.get("Description"), item.get("ExplanatoryNote"))
# ---> 16     agent_result = agent.run_sync(prompt, model_settings={'temperature': 0.0})
#      17     # Add to results all examples, including the original class name...list concatenation
#      18     for ex in [item.get("Description")] + agent_result.data.model_dump().get("examples"):
#      19         # the new "Description" is inserted at the end, so it overwrites the original one
#
# File ~/Documents/dev/coicop_classification/.venv/lib/python3.12/site-packages/pydantic_ai/agent.py:411, in Agent.run_sync(self, user_prompt, result_type, message_history, model, deps, model_settings, usage_limits, usage, infer_name)
#     409 if infer_name and self.name is None:
#     410     self._infer_name(inspect.currentframe())
# --> 411 return asyncio.get_event_loop().run_until_complete(
#     412     self.run(
#     413         user_prompt,
#     414         result_type=result_type,
#     415         message_history=message_history,
#     416         model=model,
#     417         deps=deps,
#     418         model_settings=model_settings,
#     419         usage_limits=usage_limits,
#     420         usage=usage,
#     421         infer_name=False,
#     422     )
#     423 )
#
# File ~/Documents/dev/coicop_classification/.venv/lib/python3.12/site-packages/nest_asyncio.py:92, in _patch_loop.<locals>.run_until_complete(self, future)
#      90     f._log_destroy_pending = False
#      91 while not f.done():
# ---> 92     self._run_once()
#      93     if self._stopping:
#      94         break
#
# File ~/Documents/dev/coicop_classification/.venv/lib/python3.12/site-packages/nest_asyncio.py:115, in _patch_loop.<locals>._run_once(self)
#     108     heappop(scheduled)
#     110 timeout = (
#     111     0 if ready or self._stopping
#     112     else min(max(
#     113         scheduled[0]._when - self.time(), 0), 86400) if scheduled
#     114     else None)
# --> 115 event_list = self._selector.select(timeout)
#     116 self._process_events(event_list)
#     118 end_time = self.time() + self._clock_resolution
#
# File /usr/lib/python3.12/selectors.py:468, in EpollSelector.select(self, timeout)
#     466 ready = []
#     467 try:
# --> 468     fd_event_list = self._selector.poll(timeout, max_ev)
#     469 except InterruptedError:
#     470     return ready
#
# KeyboardInterrupt:

# %%
results_df = pd.DataFrame(results)
results_df.drop(columns=["ExplanatoryNote"]).to_csv(
    "results/coicop1999_{}_{}.csv".format(
        llm_model,
        datetime.now().strftime("%Y-%m-%d_%H%M%S")),
    index=False)

# %%
failed_df = pd.DataFrame(failed_calls)
failed_df.to_csv(
    "results/failed_coicop1999_{}_{}.csv".format(
        llm_model,
        datetime.now().strftime("%Y-%m-%d_%H%M%S")),
    index=False)

# %% [markdown]
# # Combine results

# %%
result_files = [f for f in os.listdir("results/") if f.startswith("coicop1999") and f.endswith(".csv")]

# %%
results_list = []
for f in result_files:
    temp_df = pd.read_csv(os.path.join("results", f))
    results_list.append(temp_df)

results_df = pd.concat(results_list)

# %%
results_df["Code"].nunique()

# %% [markdown]
# Normalize to lowercase and remove all "other" labels

# %%
# Lowercase
results_df["Description"] = results_df["Description"].str.lower()
# Remove duplicates
results_df = results_df.drop_duplicates(ignore_index=True)
# Remove items with "other" or "miscellaneous"
results_df = results_df[~results_df["Description"].str.contains("other|miscellaneous")]

# %%
results_df["Code"].nunique()

# %%
results_df.to_csv(
    "results/consolidated_coicop1999_20250210.csv", index=False)
