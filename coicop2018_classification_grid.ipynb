# %% [markdown]
# # Structuring COICOP 2018 information for classification

# %% [markdown]
# The COICOP 2018 classification contains unstructured information for its most detailed level of classification. This notebook leverages LLMs in order to structure this information in a format which can be used for similarity search.

# %%
import os
import time # Add delays because of free API rate limits
from datetime import datetime

import pandas as pd
from ftfy import fix_text
from unidecode import unidecode

from typing import List
from pydantic import BaseModel
from pydantic_ai import Agent
from pydantic_ai.models.mistral import MistralModel
from pydantic_ai.models.groq import GroqModel

from dotenv import dotenv_values

# %%
import nest_asyncio # Fix issues with Jupyter notebook event loop
nest_asyncio.apply()

# %% [markdown]
# Import environment variables with API keys

# %%
config = dotenv_values(".env")

# %% [markdown]
# Define the Pydantic model for parsing the additional information in each COICOP 2018 level 4

# %%
class CoicopDetails(BaseModel):
    examples: List[str]

# %% [markdown]
# Read COICOP 2018 definitions

# %%
usecols = ["code","title","intro", "includes", "alsoIncludes"]

data_df = pd.read_excel(
    "coicop_2018/COICOP_2018_English_structure.xlsx", 
    usecols=usecols,)

# %% [markdown]
# Remove exclusion note from the English and French files, rename Spanish columns.
#
# Remove (ND), (SD), (D), (S) markings from the class names
#
# Filter level 4 classes only for LLMs queries

# %%
def process_subclasses(df):
    """
    Process DataFrame with the following operations:
    1. Filter rows where Code contains exactly 3 dots
    2. Combine description columns
    3. Remove classification markers from Description
    
    Args:
        df (pd.DataFrame): Input DataFrame
    
    Returns:
        pd.DataFrame: Processed DataFrame
    """
    # Create a copy to avoid modifying the original
    result_df = df.copy()
    
    # 1. Select rows where Code has exactly 2 dots
    result_df = result_df[result_df['code'].str.count(r'\.') == 3]
    
    # 2. Combine description columns
    columns_to_concat = ["intro", "includes", "alsoIncludes"]
    
    def concatenate_non_nan_columns(row):
        # Filter out NaN values and convert to string
        non_nan_values = [str(row[col]) for col in columns_to_concat if pd.notna(row[col])]
        return ' \n '.join(non_nan_values) if non_nan_values else ''
    
    result_df['description'] = result_df.apply(concatenate_non_nan_columns, axis=1)
    # Fix encoding issues
    result_df['description'] = result_df['description'].apply(fix_text)
    result_df['description'] = result_df['description'].apply(unidecode)
    result_df['description'] = result_df['description'].str.replace("_x000D_", " ")
        
    # 3. Remove classification markers from Description
    markers_pattern = r'\s*\((ND|SD|S|D)\)'
    result_df['title'] = result_df['title'].str.replace(markers_pattern, '', regex=True)
    
    return result_df[["code", "title", "description"]]

# %%
data_df = process_subclasses(data_df)

# %%
data_dict = data_df.to_dict(orient="records")

# %% [markdown]
# ## Mistral

# %% [markdown]
# Initialize PydanticAI agent to structure information

# %%
llm_model = "mistral-large-latest"

# %%
model = MistralModel(model_name=llm_model, api_key=config.get("MISTRAL_API_KEY"))
agent = Agent(
    model=model,
    retries=3,
    result_type=CoicopDetails,
    system_prompt=(
        'You are an expert data curator. You will receive a string of text '
        'with examples of items to be included into a certain classification. '
        'Your task is to transform this text into a list of self-explainig '
        'items descriptions, exploding the examples to the most granular level you can '
        'identify in the text. '
        'Each item description should contain all necessary information for classification '
        'as provided in the original text. Prefer complete descriptions rather than single words. '
        'If possible, avoid the use of ambiguous or generic terms such as `other` or `miscellaneous`. '
        'Your output should be in the same language as the input text. '
        ),
)

# %% [markdown]
# Run calls to the Agent to extract and format information

# %%
results = []
failed_calls = []
for i, item in enumerate(data_dict):
    # Print every 20 items to show progress
    if i % 20 == 0:
        print(f"Processing item {i+1} out of {len(data_dict)}")
    # Add switch to skip none items
    if item.get("description") is None:
        # No information to parse, just append existing item
        results.append(item)
        continue
    # Time delay to respect API rate limits
    time.sleep(3)
    try:
        prompt = "{}. {}".format(item.get("title"), item.get("description"))
        agent_result = agent.run_sync(prompt, model_settings={'temperature': 0.0})
        # Add to results all examples, including the original class name...list concatenation
        for ex in [item.get("title")] + agent_result.data.model_dump().get("examples"):
            # the new "Description" is inserted at the end, so it overwrites the original one
            results.append({**item, "title": ex})
    except Exception as e:
        failed_calls.append(item)
        print(f"Error processing item {i+1} out of {len(data_dict)}")
        print(item)
        print(e)
        continue
# Out:
# Processing item 1 out of 338
# Processing item 21 out of 338
# Processing item 41 out of 338
# Processing item 61 out of 338
# Processing item 81 out of 338
# Processing item 101 out of 338
# Processing item 121 out of 338
# Processing item 141 out of 338
# Processing item 161 out of 338
# Processing item 181 out of 338
# Processing item 201 out of 338
# Processing item 221 out of 338
# Processing item 241 out of 338
# Processing item 261 out of 338
# Processing item 281 out of 338
# Processing item 301 out of 338
# Processing item 321 out of 338

# %% [markdown]
# Save results and failed calls

# %%
results_df = pd.DataFrame(results)
results_df.drop(columns=["description"]).to_csv(
    "results/coicop2018_{}_{}.csv".format(
        llm_model,
        datetime.now().strftime("%Y-%m-%d_%H%M%S")),
    index=False)

# %%
failed_df = pd.DataFrame(failed_calls)
failed_df.to_csv(
    "results/failed_coicop2018_{}_{}.csv".format(
        llm_model,
        datetime.now().strftime("%Y-%m-%d_%H%M%S")),
    index=False)

# %% [markdown]
# ## Llama 3 on Groq

# %%
llm_model = "llama3-70b-8192"

# %%
model = GroqModel(
    model_name=llm_model, 
    api_key=config.get("GROQ_API_KEY"))
agent = Agent(
    model=model,
    retries=3,
    result_type=CoicopDetails,
    system_prompt=(
        'You are an expert data curator. You will receive a string of text '
        'with examples of items to be included into a certain classification. '
        'Your task is to transform this text into a list of self-explainig '
        'items descriptions, exploding the examples to the most granular level you can '
        'identify in the text. '
        'Each item description should contain all necessary information for classification '
        'as provided in the original text. Prefer complete descriptions rather than single words. '
        'If possible, avoid the use of ambiguous or generic terms such as `other` or `miscellaneous`. '
        'Your output should be in the same language as the input text. '
        ),
)

# %%
results = []
failed_calls = []
for i, item in enumerate(data_dict):
    # Print every 20 items to show progress
    if i % 20 == 0:
        print(f"Processing item {i+1} out of {len(data_dict)}")
    # Add switch to skip none items
    if item.get("description") is None:
        # No information to parse, just append existing item
        results.append(item)
        continue
    # Time delay to respect API rate limits
    time.sleep(3)
    try:
        prompt = "{}. {}".format(item.get("title"), item.get("description"))
        agent_result = agent.run_sync(prompt, model_settings={'temperature': 0.0})
        # Add to results all examples, including the original class name...list concatenation
        for ex in [item.get("title")] + agent_result.data.model_dump().get("examples"):
            # the new "Description" is inserted at the end, so it overwrites the original one
            results.append({**item, "title": ex})
    except Exception as e:
        failed_calls.append(item)
        print(f"Error processing item {i+1} out of {len(data_dict)}")
        print(item)
        print(e)
        continue
# Out:
# Processing item 1 out of 338
# Error processing item 7 out of 338
# {'code': '01.1.2.1', 'title': 'Live land animals', 'description': 'Live land animals, both domestic and wild, for human consumption as food. \n * cattle (cows; calves; common ox, zebu or humped ox; watusi, gaur, gayal, banteng and yak) \n* buffaloes (Indian or water buffaloes; arnis, or Asiatic buffaloes; Celebes anoas, or pygmy buffaloes; African buffaloes, such as the dwarf buffalo and the large Caffrarian buffalo; American bisons, known simply as buffaloes; European bisons; and beefaloes (hybrid offspring of American bisons and domestic cattle) \n* pigs \n* goats, lambs and sheep \n* poultry (chickens, ducks, geese, turkeys and guinea fowl) \n* hares and rabbits \n* horses, donkeys and other equines \n* camels, dromedaries, alpaca, llamas, guanacos, vicunas and other camelids \n* ostriches, emus, rheas, pheasants, grouse, pigeons, quails and other birds \n* snakes and other reptiles \n* spiders, scorpions, insects and worms \n* terrestrial snails \n* frogs'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>{"tool_calls":[{"id":"pending","type":"function","function":{"name":"final_result"},"parameters":{"examples":[{"Cattle":"cows, calves, common ox, zebu or humped ox, watusi, gaur, gayal, banteng and yak"},{"Buffaloes":"Indian or water buffaloes, arnis, or Asiatic buffaloes, Celebes anoas, or pygmy buffaloes, African buffaloes, American bisons, European bisons, beefaloes"},{"Pigs":""},{"Goats, lambs and sheep":""},{"Poultry":"chickens, ducks, geese, turkeys and guinea fowl"},{"Hares and rabbits":""},{"Horses, donkeys and other equines":""},{"Camels, dromedaries, alpaca, llamas, guanacos, vicunas and other camelids":""},{"Ostriches, emus, rheas, pheasants, grouse, pigeons, quails and other birds":""},{"Snakes and other reptiles":""},{"Spiders, scorpions, insects and worms":""},{"Terrestrial snails":""},{"Frogs":""}]}}]}</tool-use>'}}
# Error processing item 8 out of 338
# {'code': '01.1.2.2', 'title': 'Meat, fresh, chilled or frozen', 'description': 'Meat of all animals, both domestic and wild, fresh, chilled or frozen. \n * meat of cattle (cows; calves; common ox, zebu or humped ox; watusi; gaur; gayal, banteng and yak) \n* meat of buffaloes (Indian or water buffaloes; arnis, or wild water buffaloes: Asiatic buffalo or arni, Sulawesi anoas, or pygmy buffaloes, African buffaloes, such as the dwarf buffalo and the large Caffrarian buffalo the American bisons, known simply as buffaloes; European bisons; and beefaloes (hybrid offspring of American bisons and domestic cattle) \n* meat of pigs \n* meat of goats, lambs and sheep \n* meat of poultry (chickens, ducks, geese, turkeys and guinea fowl) \n* meat of hares and rabbits \n* meat of horses, donkeys and other equines \n* meat of camels, dromedaries, alpaca, llamas, guanacos, vicunas and other camelids \n* meat of antelopes, deer, boars and kangaroos \n* meat of ostriches, emus, rheas, pheasants, grouse, pigeons, quails and other birds \n* meat of snakes, alligators and other reptiles \n* spiders, scorpions, insects, and worms (not-live) \n* terrestrial snails \n* frogs \n * minced meat of the animals listed directly above \n* meat of seals, walruses, whales and other marine mammals'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>{"tool_calls":[{"id":"pending","type":"function","function":{"name":"final_result"},"parameters":{"examples":[{"Meat of cattle (fresh, chilled or frozen) - cows, calves, common ox, zebu or humped ox, watusi, gaur, gayal, banteng, yak"},{"Meat of buffaloes (fresh, chilled or frozen) - Indian or water buffaloes, arnis, Asiatic buffalo or arni, Sulawesi anoas, pygmy buffaloes, African buffaloes, dwarf buffalo, large Caffrarian buffalo, American bisons, European bisons, beefaloes"},{"Meat of pigs (fresh, chilled or frozen)"},{"Meat of goats, lambs and sheep (fresh, chilled or frozen)"},{"Meat of poultry (fresh, chilled or frozen) - chickens, ducks, geese, turkeys, guinea fowl"},{"Meat of hares and rabbits (fresh, chilled or frozen)"},{"Meat of horses, donkeys and other equines (fresh, chilled or frozen)"},{"Meat of camels, dromedaries, alpaca, llamas, guanacos, vicunas and other camelids (fresh, chilled or frozen)"},{"Meat of antelopes, deer, boars and kangaroos (fresh, chilled or frozen)"},{"Meat of ostriches, emus, rheas, pheasants, grouse, pigeons, quails and other birds (fresh, chilled or frozen)"},{"Meat of snakes, alligators and other reptiles (fresh, chilled or frozen)"},{"Spiders, scorpions, insects, and worms (not-live)"},{"Terrestrial snails"},{"Frogs"},{"Minced meat of the above animals"},{"Meat of seals, walruses, whales and other marine mammals (fresh, chilled or frozen)"}]}}]}</tool-use>'}}
# Error processing item 15 out of 338
# {'code': '01.1.3.4', 'title': 'Other seafood, live, fresh, chilled or frozen', 'description': '* crabs, lobsters, crayfish, krill, sea spiders, shrimp, prawns and other crustaceans, live, fresh, chilled or frozen  \n* cuttlefish; squid; octopuses; sea snails; abalone; and bivalves, such as oysters, scallops, mussels, clams, cockles, ark shells and other molluscs, live, fresh, chilled or frozen \n* sea urchins, beche-de-mer (sea cucumbers), jellyfish and other aquatic invertebrates, live, fresh, chilled or frozen'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>{"tool_calls":[{"id":"pending","type":"function","function":{"name":"final_result"},"parameters":{"examples":["Live crabs","Fresh lobsters","Chilled crayfish","Frozen krill","Live sea spiders","Fresh shrimp","Chilled prawns","Frozen crustaceans","Live cuttlefish","Fresh squid","Chilled octopuses","Frozen sea snails","Live abalone","Fresh oysters","Chilled scallops","Frozen mussels","Live clams","Fresh cockles","Chilled ark shells","Frozen molluscs","Live sea urchins","Fresh beche-de-mer (sea cucumbers)","Chilled jellyfish","Frozen aquatic invertebrates"]}}}]}</tool-use>'}}
# Processing item 21 out of 338
# Processing item 41 out of 338
# Processing item 61 out of 338
# Error processing item 64 out of 338
# {'code': '01.2.3.0', 'title': 'Tea, maté and other plant-derived products for infusion', 'description': '* green tea, unfermented; black tea, fermented; and tea, mate and other plant products, partly fermented, for infusion \n* tea substitutes and tea extracts and essences \n * fruit and herbal teas \n* rooibos tea \n* instant tea \n* iced tea'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>{"tool_calls": [{"id": "pending", "type": "function", "function": {"name": "final_result"}, "parameters": {"examples": ["Green tea, unfermented", "Black tea, fermented", "Tea, mate and other plant products, partly fermented, for infusion", "Tea substitutes", "Tea extracts", "Tea essences", "Fruit teas", "Herbal teas", "Rooibos tea", "Instant tea", "Iced tea"]}}}]}</tool-use>'}}
# Processing item 81 out of 338
# Processing item 101 out of 338
# Processing item 121 out of 338
# Processing item 141 out of 338
# Processing item 161 out of 338
# Processing item 181 out of 338
# Processing item 201 out of 338
# Processing item 221 out of 338
# Processing item 241 out of 338
# Processing item 261 out of 338
# Error processing item 269 out of 338
# {'code': '11.2.0.2', 'title': 'Holiday centres, camping sites, youth hostels and similar accommodation services', 'description': '* holiday villages and holiday centres \n* camping sites, onsite (non-mobile) caravans and boats, camping grounds and recreational vehicle and trailer parks \n* youth hostels and mountain refuges \n* bungalows, chalets, housekeeping cottages and cabins'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>{"tool_calls": [{"id": "pending", "type": "function", "function": {"name": "final_result"}, "parameters": {"examples": ["Holiday villages", "Holiday centres", "Camping sites", "Onsite (non-mobile) caravans", "Boats", "Camping grounds", "Recreational vehicle parks", "Trailer parks", "Youth hostels", "Mountain refuges", "Bungalows", "Chalets", "Housekeeping cottages", "Cabins"]}}}]}</tool-use>'}}
# Error processing item 274 out of 338
# {'code': '12.1.3.0', 'title': 'Insurance connected with dwellings', 'description': '* service charges paid by owner-occupiers and by tenants for the kinds of insurance typically taken out by tenants against fire, theft, water damage and so on \n* service charges paid by owner-occupiers and by tenants for household contents insurance'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>{"tool_calls": [{"id": "pending", "type": "function", "function": {"name": "final_result"}, "parameters": {"examples": ["Insurance against fire for owner-occupiers", "Insurance against theft for owner-occupiers", "Insurance against water damage for owner-occupiers", "Insurance against fire for tenants", "Insurance against theft for tenants", "Insurance against water damage for tenants", "Household contents insurance for owner-occupiers", "Household contents insurance for tenants"]}}}]}</tool-use>'}}
# Processing item 281 out of 338
# Error processing item 286 out of 338
# {'code': '13.1.3.2', 'title': 'Personal grooming treatments', 'description': '* facial beauty treatments, depilation, solarium, pedicure, body care, manicure, thalassotherapy, Turkish baths, saunas, non-medical massages and so on \n* diet clubs and tattoo and piercing services'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>{"tool_calls":[{"id":"pending","type":"function","function":{"name":"final_result"},"parameters":{"examples":[{"Facial beauty treatments":"Facial beauty treatments, including facials, skin rejuvenation, and other facial care services"},{"Depilation":"Depilation services, including waxing, sugaring, and threading"},{"Solarium":"Solarium services, including sunbeds and spray tanning"},{"Pedicure":"Pedicure services, including nail care and foot treatments"},{"Body care":"Body care services, including body wraps, scrubs, and polishes"},{"Manicure":"Manicure services, including nail care and hand treatments"},{"Thalassotherapy":"Thalassotherapy services, including seawater-based treatments and therapies"},{"Turkish baths":"Turkish baths, including steam baths and sauna sessions"},{"Saunas":"Sauna services, including traditional and infrared sauna sessions"},{"Non-medical massages":"Non-medical massage services, including relaxation and therapeutic massages"},{"Diet clubs":"Diet clubs, including weight loss programs and nutrition counseling"},{"Tattoo and piercing services":"Tattoo and piercing services, including tattoo design and piercing procedures"}]}}]}</tool-use>'}}
# Processing item 301 out of 338
# Processing item 321 out of 338

# %%
results_df = pd.DataFrame(results)
results_df.drop(columns=["description"]).to_csv(
    "results/coicop2018_{}_{}.csv".format(
        llm_model,
        datetime.now().strftime("%Y-%m-%d_%H%M%S")),
    index=False)

# %%
failed_df = pd.DataFrame(failed_calls)
failed_df.to_csv(
    "results/failed_coicop2018_{}_{}.csv".format(
        llm_model,
        datetime.now().strftime("%Y-%m-%d_%H%M%S")),
    index=False)

# %% [markdown]
# ## Mixtral on Groq

# %%
llm_model = "mixtral-8x7b-32768"

# %%
model = GroqModel(
    model_name=llm_model, 
    api_key=config.get("GROQ_API_KEY"))
agent = Agent(
    model=model,
    retries=3,
    result_type=CoicopDetails,
    system_prompt=(
        'You are an expert data curator. You will receive a string of text '
        'with examples of items to be included into a certain classification. '
        'Your task is to transform this text into a list of self-explainig '
        'items descriptions, exploding the examples to the most granular level you can '
        'identify in the text. '
        'Each item description should contain all necessary information for classification '
        'as provided in the original text. Prefer complete descriptions rather than single words. '
        'If possible, avoid the use of ambiguous or generic terms such as `other` or `miscellaneous`. '
        'Your output should be in the same language as the input text. '
        ),
)

# %%
results = []
failed_calls = []
for i, item in enumerate(data_dict):
    # Print every 20 items to show progress
    if i % 20 == 0:
        print(f"Processing item {i+1} out of {len(data_dict)}")
    # Add switch to skip none items
    if item.get("description") is None:
        # No information to parse, just append existing item
        results.append(item)
        continue
    # Time delay to respect API rate limits
    time.sleep(3)
    try:
        prompt = "{}. {}".format(item.get("title"), item.get("description"))
        agent_result = agent.run_sync(prompt, model_settings={'temperature': 0.0})
        # Add to results all examples, including the original class name...list concatenation
        for ex in [item.get("title")] + agent_result.data.model_dump().get("examples"):
            # the new "Description" is inserted at the end, so it overwrites the original one
            results.append({**item, "title": ex})
    except Exception as e:
        failed_calls.append(item)
        print(f"Error processing item {i+1} out of {len(data_dict)}")
        print(item)
        print(e)
        continue
# Out:
# Processing item 1 out of 338
# Error processing item 4 out of 338
# {'code': '01.1.1.4', 'title': 'Breakfast cereals', 'description': '* cornflakes, oatmeal and oat flakes, muesli, granola and puffed cereals including puffed rice cakes \n* breakfast cereals with nuts or dried fruit'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"cornflakes",\n\t\t\t\t"oatmeal and oat flakes",\n\t\t\t\t"muesli",\n\t\t\t\t"granola",\n\t\t\t\t"puffed cereals including puffed rice cakes",\n\t\t\t\t"breakfast cereals with nuts",\n\t\t\t\t"breakfast cereals with dried fruit"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 5 out of 338
# {'code': '01.1.1.5', 'title': 'Macaroni, noodles, couscous and similar pasta products', 'description': '* uncooked pasta, whether stuffed or not, and couscous \n* uncooked dumplings, ravioli and similar products'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"uncooked pasta, whether stuffed or not, and couscous",\n\t\t\t\t"uncooked dumplings, ravioli and similar products"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 7 out of 338
# {'code': '01.1.2.1', 'title': 'Live land animals', 'description': 'Live land animals, both domestic and wild, for human consumption as food. \n * cattle (cows; calves; common ox, zebu or humped ox; watusi, gaur, gayal, banteng and yak) \n* buffaloes (Indian or water buffaloes; arnis, or Asiatic buffaloes; Celebes anoas, or pygmy buffaloes; African buffaloes, such as the dwarf buffalo and the large Caffrarian buffalo; American bisons, known simply as buffaloes; European bisons; and beefaloes (hybrid offspring of American bisons and domestic cattle) \n* pigs \n* goats, lambs and sheep \n* poultry (chickens, ducks, geese, turkeys and guinea fowl) \n* hares and rabbits \n* horses, donkeys and other equines \n* camels, dromedaries, alpaca, llamas, guanacos, vicunas and other camelids \n* ostriches, emus, rheas, pheasants, grouse, pigeons, quails and other birds \n* snakes and other reptiles \n* spiders, scorpions, insects and worms \n* terrestrial snails \n* frogs'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"Cattle: cows, calves, common ox (zebu or humped ox), Watusi, Gaur, Gayal, Banteng, and Yak",\n\t\t\t\t"Buffaloes: Indian or water buffaloes, Arnis or Asiatic buffaloes, Celebes anoas or pygmy buffaloes, African buffaloes (dwarf buffalo and large Caffrarian buffalo), American bisons (buffaloes), European bisons, and beefaloes (hybrid offspring of American bisons and domestic cattle)",\n\t\t\t\t"Pigs",\n\t\t\t\t"Goats, lambs, and sheep",\n\t\t\t\t"Poultry: chickens, ducks, geese, turkeys, and guinea fowl",\n\t\t\t\t"Hares and rabbits",\n\t\t\t\t"Horses, donkeys, and other equines",\n\t\t\t\t"Camels, dromedaries, alpaca, llamas, guanacos, vicunas, and other camelids",\n\t\t\t\t"Ostriches, emus, rheas, pheasants, grouse, pigeons, quails, and other birds",\n\t\t\t\t"Snakes and other reptiles",\n\t\t\t\t"Spiders, scorpions, insects, and worms",\n\t\t\t\t"Terrestrial snails",\n\t\t\t\t"Frogs"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 10 out of 338
# {'code': '01.1.2.4', 'title': 'Offal, blood and other parts of slaughtered animals, fresh, chilled or frozen, dried, salted, in brine or smoked', 'description': 'Offal, blood and other parts of slaughtered animals, fresh, chilled or frozen, dried, salted, in brine or smoked. \n * bones \n* pork heads, tails and ears; and chicken feet'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"offal (heart, liver, kidney, etc.) fresh, chilled or frozen",\n\t\t\t\t"blood fresh, chilled or frozen",\n\t\t\t\t"dried blood",\n\t\t\t\t"salted blood",\n\t\t\t\t"blood in brine",\n\t\t\t\t"smoked blood",\n\t\t\t\t"bones (whole or cut) fresh, chilled or frozen",\n\t\t\t\t"pork heads fresh, chilled or frozen",\n\t\t\t\t"pork tails fresh, chilled or frozen",\n\t\t\t\t"pork ears fresh, chilled or frozen",\n\t\t\t\t"chicken feet fresh, chilled or frozen"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 12 out of 338
# {'code': '01.1.3.1', 'title': 'Fish, live, fresh, chilled or frozen', 'description': 'Fish, live, fresh, chilled or frozen. \n * fish, live, purchased as food \n* fish, fresh, chilled or frozen \n* fish fillets and meat, whether minced or not, fresh, chilled or frozen'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"fish, live, purchased as food",\n\t\t\t\t"fish, fresh, chilled or frozen",\n\t\t\t\t"fish fillets and meat, whether minced or not, fresh, chilled or frozen"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 14 out of 338
# {'code': '01.1.3.3', 'title': 'Fish preparations', 'description': 'Prepared foodstuffs consisting of fish, whether frozen or not. \n * fillets covered only with batter or breadcrumbs, whether or not frozen \n* canned fish \n* surimi and other imitation crabmeat'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"Fillets covered only with batter or breadcrumbs, whether or not frozen",\n\t\t\t\t"Canned fish",\n\t\t\t\t"Surimi and other imitation crabmeat"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 15 out of 338
# {'code': '01.1.3.4', 'title': 'Other seafood, live, fresh, chilled or frozen', 'description': '* crabs, lobsters, crayfish, krill, sea spiders, shrimp, prawns and other crustaceans, live, fresh, chilled or frozen  \n* cuttlefish; squid; octopuses; sea snails; abalone; and bivalves, such as oysters, scallops, mussels, clams, cockles, ark shells and other molluscs, live, fresh, chilled or frozen \n* sea urchins, beche-de-mer (sea cucumbers), jellyfish and other aquatic invertebrates, live, fresh, chilled or frozen'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"crabs, lobsters, crayfish, krill, sea spiders, shrimp, prawns and other crustaceans, live, fresh, chilled or frozen",\n\t\t\t\t"cuttlefish; squid; octopuses; sea snails; abalone; and bivalves, such as oysters, scallops, mussels, clams, cockles, ark shells and other molluscs, live, fresh, chilled or frozen",\n\t\t\t\t"sea urchins, beche-de-mer (sea cucumbers), jellyfish and other aquatic invertebrates, live, fresh, chilled or frozen"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 16 out of 338
# {'code': '01.1.3.5', 'title': 'Other seafood, dried, salted, in brine or smoked', 'description': 'Other seafood, as listed in subclass 01.1.3.4, dried, salted, in brine or smoked.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"dried seafood other than those listed in subclass 01.1.3.4",\n\t\t\t\t"salted seafood other than those listed in subclass 01.1.3.4",\n\t\t\t\t"seafood in brine other than those listed in subclass 01.1.3.4",\n\t\t\t\t"smoked seafood other than those listed in subclass 01.1.3.4"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 20 out of 338
# {'code': '01.1.4.2', 'title': 'Skimmed milk', 'description': 'Skimmed and semi-skimmed milk of cattle and buffaloes, sheep and goats, camels and other animals'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"Skimmed milk of cattle",\n\t\t\t\t"Skimmed milk of buffaloes",\n\t\t\t\t"Semi-skimmed milk of cattle",\n\t\t\t\t"Semi-skimmed milk of buffaloes",\n\t\t\t\t"Skimmed milk of sheep",\n\t\t\t\t"Semi-skimmed milk of sheep",\n\t\t\t\t"Skimmed milk of goats",\n\t\t\t\t"Semi-skimmed milk of goats",\n\t\t\t\t"Skimmed milk of camels",\n\t\t\t\t"Semi-skimmed milk of camels",\n\t\t\t\t"Skimmed milk from other animals"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Processing item 21 out of 338
# Error processing item 23 out of 338
# {'code': '01.1.4.5', 'title': 'Cheese', 'description': 'All kinds of cheese (fresh, hard, semi-hard, blue cheese and cottage cheese) and curd, from animal and non-animal milk.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"Fresh cheese",\n\t\t\t\t"Hard cheese",\n\t\t\t\t"Semi-hard cheese",\n\t\t\t\t"Blue cheese",\n\t\t\t\t"Cottage cheese",\n\t\t\t\t"Cheese from animal milk",\n\t\t\t\t"Cheese from non-animal milk",\n\t\t\t\t"Curd from animal milk",\n\t\t\t\t"Curd from non-animal milk"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 27 out of 338
# {'code': '01.1.4.9', 'title': 'Other dairy products', 'description': '* whey and casein \n* cream, concentrated or containing added sugar or other sweeteners; and cream powder \n* other products consisting of milk constituents, milk protein concentrates, and products obtained from whey'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"whey and casein",\n\t\t\t\t"cream, concentrated or containing added sugar or other sweeteners; and cream powder",\n\t\t\t\t"other products consisting of milk constituents, milk protein concentrates, and products obtained from whey"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 30 out of 338
# {'code': '01.1.5.3', 'title': 'Margarine and similar preparations', 'description': '* margarine \n* diet margarine'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool\\_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"margarine",\n\t\t\t\t"diet margarine"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 31 out of 338
# {'code': '01.1.5.9', 'title': 'Other animal oils and fats', 'description': '* pig fat and lard, including leaves or other spices \n* fat from cattle, buffaloes, sheep, goats and poultry \n* greaves fat \n* oils and fats of fish'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"pig fat and lard, including leaves or other spices",\n\t\t\t\t"fat from cattle, buffaloes, sheep, goats and poultry",\n\t\t\t\t"greaves fat",\n\t\t\t\t"oils and fats of fish"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 32 out of 338
# {'code': '01.1.6.1', 'title': 'Dates, figs and tropical fruits, fresh', 'description': '* dates \n* figs \n* avocados \n* sweet/dessert bananas \n* mangoes, guavas and mangosteens \n* papayas \n* pineapples \n* coconuts \n* breadfruits \n* other tropical and subtropical fruits, fresh'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"Dates, fresh",\n\t\t\t\t"Figs, fresh",\n\t\t\t\t"Avocados, fresh",\n\t\t\t\t"Sweet/dessert bananas, fresh",\n\t\t\t\t"Mangoes, fresh",\n\t\t\t\t"Guavas, fresh",\n\t\t\t\t"Mangosteens, fresh",\n\t\t\t\t"Papayas, fresh",\n\t\t\t\t"Pineapples, fresh",\n\t\t\t\t"Coconuts, fresh",\n\t\t\t\t"Breadfruits, fresh",\n\t\t\t\t"Other tropical and subtropical fruits, fresh"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 35 out of 338
# {'code': '01.1.6.4', 'title': 'Berries, fresh', 'description': '* currants and gooseberries \n* raspberries \n* blackberries \n* mulberries and loganberries \n* strawberries \n* other berries, fresh'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool\\_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"currants - small, round, and seedless black or red berries that are often used in cooking and baking",\n\t\t\t\t"gooseberries - small, round, and green or red berries that have a tart flavor and are often used in jams and pies",\n\t\t\t\t"raspberries - small, red, juicy, and aggregate fruit that is made up of many tiny drupelets",\n\t\t\t\t"blackberries - small, black, and juicy fruit that is similar to raspberries but is often larger and has a stronger flavor",\n\t\t\t\t"mulberries - large, black or red, juicy fruit that grows on mulberry trees and is often used in pies and jams",\n\t\t\t\t"loganberries - a hybrid fruit that is a cross between a blackberry and a raspberry, and is typically large, juicy, and black in color",\n\t\t\t\t"strawberries - small, red, and juicy fruit that has a distinctive flavor and is often used in desserts and drinks"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 36 out of 338
# {'code': '01.1.6.5', 'title': 'Other fruits, fresh', 'description': '* grapes \n* kiwi fruits \n* cantaloupes and other melons \n* watermelons \n* pomegranates \n* other fruits or mixtures of fruit, fresh, n.e.c.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"grapes - fresh fruit",\n\t\t\t\t"kiwi fruits - fresh fruit",\n\t\t\t\t"cantaloupes - fresh fruit",\n\t\t\t\t"other melons - fresh fruit",\n\t\t\t\t"watermelons - fresh fruit",\n\t\t\t\t"pomegranates - fresh fruit",\n\t\t\t\t"other fruits - fresh fruit, not specified",\n\t\t\t\t"mixtures of fruit - fresh fruit, not specified"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 37 out of 338
# {'code': '01.1.6.6', 'title': 'Fruits, frozen', 'description': 'Fruits cooked or uncooked, frozen, whether or not they contain added sugar or other sweetening matter.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"Frozen whole strawberries",\n\t\t\t\t"Frozen raspberries",\n\t\t\t\t"Frozen blueberries",\n\t\t\t\t"Frozen mixed berries",\n\t\t\t\t"Frozen peach slices",\n\t\t\t\t"Frozen pineapple chunks",\n\t\t\t\t"Frozen mango chunks",\n\t\t\t\t"Cooked frozen apples",\n\t\t\t\t"Cooked frozen pears",\n\t\t\t\t"Cooked frozen peaches",\n\t\t\t\t"Cooked frozen mixed fruits",\n\t\t\t\t"Uncooked frozen grapes",\n\t\t\t\t"Uncooked frozen cherries",\n\t\t\t\t"Uncooked frozen cranberries",\n\t\t\t\t"Uncooked frozen rhubarb",\n\t\t\t\t"Frozen fruit purees",\n\t\t\t\t"Frozen fruit juices",\n\t\t\t\t"Frozen fruit smoothies",\n\t\t\t\t"Frozen fruit yogurts",\n\t\t\t\t"Frozen fruit ice creams",\n\t\t\t\t"Frozen fruit sorbets",\n\t\t\t\t"Frozen fruit with added sugar",\n\t\t\t\t"Frozen fruit with other sweetening matter"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 38 out of 338
# {'code': '01.1.6.7', 'title': 'Fruits, dried and dehydrated', 'description': '* raisins \n* prunes \n* dried apricots \n* dried coconuts \n* other dried fruits'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"dried fruit: raisins",\n\t\t\t\t"dried fruit: prunes",\n\t\t\t\t"dried fruit: dried apricots",\n\t\t\t\t"dried fruit: dried coconuts"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Processing item 41 out of 338
# Error processing item 41 out of 338
# {'code': '01.1.7.1', 'title': 'Leafy or stem vegetables, fresh or chilled', 'description': '* asparagus \n* cabbages \n* cauliflower and broccoli \n* lettuce and chicory \n* spinach \n* artichokes \n* other leafy or stem vegetables, fresh or chilled'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"asparagus - Leafy or stem vegetable, fresh or chilled",\n\t\t\t\t"cabbages - Leafy or stem vegetable, fresh or chilled",\n\t\t\t\t"cauliflower and broccoli - Leafy or stem vegetable, fresh or chilled",\n\t\t\t\t"lettuce and chicory - Leafy or stem vegetable, fresh or chilled",\n\t\t\t\t"spinach - Leafy or stem vegetable, fresh or chilled",\n\t\t\t\t"artichokes - Leafy or stem vegetable, fresh or chilled",\n\t\t\t\t"other leafy or stem vegetables, fresh or chilled - Please specify"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 50 out of 338
# {'code': '01.1.8.1', 'title': 'Cane sugar and beet sugar', 'description': '* cane and beet sugar, raw and refined, powdered, crystallized or in lumps'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"cane sugar, raw",\n\t\t\t\t"cane sugar, refined, powdered",\n\t\t\t\t"cane sugar, refined, crystallized",\n\t\t\t\t"cane sugar, refined, in lumps",\n\t\t\t\t"beet sugar, raw",\n\t\t\t\t"beet sugar, refined, powdered",\n\t\t\t\t"beet sugar, refined, crystallized",\n\t\t\t\t"beet sugar, refined, in lumps"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 51 out of 338
# {'code': '01.1.8.2', 'title': 'Other sugars and sugar substitutes', 'description': '* sugars other than cane and beet sugar (e.g., coconut sugar) \n* stevia \n* glucose and glucose syrup, and fructose and fructose syrup \n* lactose and lactose syrup \n* invert sugar \n* artificial honey, saccharin and other artificial sweeteners \n* refined cane and beet sugar, in solid form, containing added flavouring or colouring matter \n* maple sugar and maple syrup, caramel, molasses, and sugars and sugar syrups n.e.c.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"coconut sugar",\n\t\t\t\t"stevia",\n\t\t\t\t"glucose and glucose syrup, fructose and fructose syrup",\n\t\t\t\t"lactose and lactose syrup",\n\t\t\t\t"invert sugar",\n\t\t\t\t"artificial honey, saccharin and other artificial sweeteners",\n\t\t\t\t"refined cane and beet sugar, in solid form, containing added flavouring or colouring matter",\n\t\t\t\t"maple sugar and maple syrup, caramel, molasses"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 52 out of 338
# {'code': '01.1.8.3', 'title': 'Jams, marmalades, fruit jellies, purées and pastes, and honey', 'description': '* jams, marmalades, compotes, fruit jellies, purees and pastes \n* honey \n * lemon curd and other fruit curd'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"jams, marmalades, compotes, fruit jellies, purees and pastes",\n\t\t\t\t"honey",\n\t\t\t\t"lemon curd and other fruit curd"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 53 out of 338
# {'code': '01.1.8.4', 'title': 'Nut purées, nut butters and nut pastes', 'description': '* peanut butter \n* other nut butters, such as almond butter, cashew butter, hazelnut butter, macadamia nut butter, pecan butter, pistachio butter and walnut butter'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"Nut purée made from peanuts",\n\t\t\t\t"Peanut butter",\n\t\t\t\t"Nut butter made from almonds",\n\t\t\t\t"Almond butter",\n\t\t\t\t"Nut butter made from cashews",\n\t\t\t\t"Cashew butter",\n\t\t\t\t"Nut butter made from hazelnuts",\n\t\t\t\t"Hazelnut butter",\n\t\t\t\t"Nut butter made from macadamia nuts",\n\t\t\t\t"Macadamia nut butter",\n\t\t\t\t"Nut butter made from pecans",\n\t\t\t\t"Pecan butter",\n\t\t\t\t"Nut butter made from pistachios",\n\t\t\t\t"Pistachio butter",\n\t\t\t\t"Nut butter made from walnuts",\n\t\t\t\t"Walnut butter"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 54 out of 338
# {'code': '01.1.8.5', 'title': 'Chocolate, cocoa and cocoa-based food products', 'description': '* cocoa (including cocoa beans) and cocoa powder for all purposes \n* chocolate in bars or slabs \n* chocolate- and cocoa-based foods and cocoa-based desserts \n* chocolate- and cocoa-based creams and spreads \n* chocolate-covered food products, if the product is composed mainly of chocolate'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"cocoa (including cocoa beans) and cocoa powder for all purposes",\n\t\t\t\t"chocolate in bars or slabs",\n\t\t\t\t"chocolate- and cocoa-based foods and cocoa-based desserts",\n\t\t\t\t"chocolate- and cocoa-based creams and spreads",\n\t\t\t\t"chocolate-covered food products, if the product is composed mainly of chocolate"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 56 out of 338
# {'code': '01.1.8.9', 'title': 'Other sugar confectionery and desserts n.e.c.', 'description': '* vegetables, fruit, nuts, fruit peels and other parts of plants, preserved with sugar \n* chewing gum, toffees, lollies, candies, pastilles \n* white chocolate \n* other confectionery products \n* desserts n.e.c.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"vegetables, fruit, nuts, fruit peels and other parts of plants, preserved with sugar",\n\t\t\t\t"chewing gum, toffees, lollies, candies, pastilles",\n\t\t\t\t"white chocolate",\n\t\t\t\t"other confectionery products",\n\t\t\t\t"desserts n.e.c."\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 57 out of 338
# {'code': '01.1.9.1', 'title': 'Ready-made food', 'description': 'Prepared food and meals that either can be eaten as is or after heating but that do not require cooking, or are assembled and portioned in such a way that they can be cooked. They may contain mixed ingredients and can be fresh, frozen, or dehydrated or instant. They can include sauces and dressings which, especially when the food is fresh, may be provided in separate containers. Sometimes, disposable forks, knives, spoons or chopsticks are packed together with the food. \n * precooked dishes containing stuffed pasta, rice or other cereals, such as couscous, including vegetables, meat, fish, cheese or other ingredients; and ready-to- eat dumplings, ravioli, noodles and similar dishes, including sauce \n* ready-made dishes and meals based on precooked meat, meat substitutes or fish \n* TV dinners \n* mixed salads and other prepared dishes and meals based on vegetables, pulses or potatoes and also including other ingredients, such as meat, fish and cheese \n* sandwiches, pizzas, quiches, meat or fish pies, whether frozen or not \n* omelettes, crepes and other food products based on eggs when precooked and served as a main dish \n* ready-made soups including dehydrated and instant soups and stews; \n* other prepared ready-made dishes and meals, n.e.c. \n * meal-kits'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"Precooked dishes containing stuffed pasta, rice or other cereals, such as couscous, with vegetables, meat, fish, cheese or other ingredients, and ready-to-eat dumplings, ravioli, noodles and similar dishes, including sauce",\n\t\t\t\t"Ready-made dishes and meals based on precooked meat, meat substitutes or fish, such as TV dinners",\n\t\t\t\t"Mixed salads and other prepared dishes and meals based on vegetables, pulses or potatoes and also including other ingredients, such as meat, fish and cheese",\n\t\t\t\t"Sandwiches, pizzas, quiches, meat or fish pies, whether frozen or not",\n\t\t\t\t"Omelettes, crepes and other food products based on eggs when precooked and served as a main dish",\n\t\t\t\t"Ready-made soups including dehydrated and instant soups and stews",\n\t\t\t\t"Other prepared ready-made dishes and meals, n.e.c.",\n\t\t\t\t"Meal-kits"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 58 out of 338
# {'code': '01.1.9.2', 'title': 'Baby food', 'description': 'Food and beverages intended for baby use exclusively. \n * baby formula (powdered, condensed and evaporated milk for baby use) \n* baby rice cereals and flours for baby food \n* homogenized baby food'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"Baby formula (powdered, condensed and evaporated milk specifically designed for baby use)",\n\t\t\t\t"Baby rice cereals and flours, specifically produced for baby food",\n\t\t\t\t"Homogenized baby food, prepared and packaged for exclusive baby use"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 60 out of 338
# {'code': '01.1.9.4', 'title': 'Spices, culinary herbs and seeds', 'description': '* pepper, pimento, ginger and other spices \n* parsley, rosemary, thyme and other culinary herbs \n* poppy seed, sesame seed, linseed and other seeds'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"pepper - a pungent spice derived from the dried berries of the Piper nigrum plant",\n\t\t\t\t"pimento - a sweet, mildly flavored variety of chili pepper",\n\t\t\t\t"ginger - a spice derived from the rhizome of the Zingiber officinale plant",\n\t\t\t\t"parsley - a bright green, leafy herb used for flavoring and garnishing",\n\t\t\t\t"rosemary - a fragrant, needle-like herb used for flavoring and medicinal purposes",\n\t\t\t\t"thyme - a small, aromatic herb used for flavoring and medicinal purposes",\n\t\t\t\t"poppy seed - a small, kidney-shaped seed often used as a topping or ingredient in baked goods",\n\t\t\t\t"sesame seed - a small, oval-shaped seed often used in cooking and as a topping",\n\t\t\t\t"linseed - a small, flat seed derived from the flax plant, often used as a nutritional supplement or in cooking"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Processing item 61 out of 338
# Error processing item 62 out of 338
# {'code': '01.2.1.0', 'title': 'Fruit and vegetable juices', 'description': '* fruit and vegetable juices, unfermented and not containing added alcohol, whether or not they contain added sugar or other sweetening matter \n* syrups of fruit and vegetables and concentrates of fruit and vegetables \n* powdered juices'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"fruit and vegetable juices, unfermented and not containing added alcohol, whether or not they contain added sugar or other sweetening matter",\n\t\t\t\t"syrups of fruit and vegetables and concentrates of fruit and vegetables",\n\t\t\t\t"powdered juices"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 70 out of 338
# {'code': '02.1.1.0', 'title': 'Spirits and liquors', 'description': '* eaux de vie, liqueurs and other spirits with a high alcohol content \n* mead \n* pomace brandies, such as pisco, grappa and marc \n* aperitifs, other than wine-based aperitifs'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"eaux de vie with a high alcohol content",\n\t\t\t\t"liqueurs with a high alcohol content",\n\t\t\t\t"spirits with a high alcohol content",\n\t\t\t\t"mead",\n\t\t\t\t"pisco - a pomace brandy",\n\t\t\t\t"grappa - a pomace brandy",\n\t\t\t\t"marc - a pomace brandy",\n\t\t\t\t"apertifs, not wine-based"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 71 out of 338
# {'code': '02.1.2.1', 'title': 'Wine from grapes', 'description': '* wine from grapes \n* fortified wines, such as vermouth, sherry and port wine \n* champagne and other sparkling wines from grapes \n* ice wine \n* low-alcohol and non-alcoholic wine \n* wine-based aperitifs'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"wine from grapes",\n\t\t\t\t"fortified wines, such as vermouth, sherry and port wine",\n\t\t\t\t"champagne and other sparkling wines from grapes",\n\t\t\t\t"ice wine",\n\t\t\t\t"low-alcohol and non-alcoholic wine",\n\t\t\t\t"wine-based aperitifs"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 73 out of 338
# {'code': '02.1.3.0', 'title': 'Beer', 'description': '* all kinds of beers, such as ale, lager, stout and porter \n* low-alcohol beer and non-alcoholic beer'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"ale",\n\t\t\t\t"lager",\n\t\t\t\t"stout",\n\t\t\t\t"porter",\n\t\t\t\t"low-alcohol beer",\n\t\t\t\t"non-alcoholic beer"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 77 out of 338
# {'code': '02.3.0.2', 'title': 'Cigars', 'description': 'Includes: \n* cigars \n* cigars that are purchased in bars and restaurants, provided that a service charge is not applied'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"cigar",\n\t\t\t\t"cigar purchased in bars and restaurants with service charge",\n\t\t\t\t"cigar purchased in bars and restaurants without service charge"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 78 out of 338
# {'code': '02.3.0.9', 'title': 'Other tobacco products', 'description': '* pipe tobacco, chewing tobacco, hookah blends, snus and snuff \n* cigarette tobacco and tobacco leaf \n* cigarette papers and single-use filters which are consumed with the cigarette \n* refills for electronic cigarettes, with or without nicotine \n* tobacco that is consumed with a shisha or a hookah pipe if consumed at home'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"pipe tobacco",\n\t\t\t\t"chewing tobacco",\n\t\t\t\t"hookah blends",\n\t\t\t\t"snus",\n\t\t\t\t"snuff",\n\t\t\t\t"cigarette tobacco",\n\t\t\t\t"tobacco leaf",\n\t\t\t\t"cigarette papers",\n\t\t\t\t"single-use filters",\n\t\t\t\t"refills for electronic cigarettes with nicotine",\n\t\t\t\t"refills for electronic cigarettes without nicotine",\n\t\t\t\t"tobacco consumed with a shisha or a hookah pipe if consumed at home"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 79 out of 338
# {'code': '02.4.0.0', 'title': 'Narcotics', 'description': '* marijuana, opium, cocaine and their derivatives \n* other vegetable-based narcotics, such as betel leaves, betel nuts, cola nuts, kava, khat, and psilocybin mushroom \n* other narcotics, including chemicals and synthetic drugs'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"marijuana - a psychoactive drug derived from the Cannabis plant",\n\t\t\t\t"opium - a highly addictive drug derived from the poppy plant",\n\t\t\t\t"cocaine - a powerful stimulant derived from the leaves of the coca plant",\n\t\t\t\t"betel leaves - a mild stimulant chewed with areca nut in many parts of Asia",\n\t\t\t\t"betel nuts - the seed of the Areca palm, often chewed with betel leaves",\n\t\t\t\t"cola nuts - the seeds of the Cola acuminata tree, used as a flavoring agent",\n\t\t\t\t"kava - a mild sedative and anesthetic derived from the roots of the Piper methysticum plant",\n\t\t\t\t"khat - a mild stimulant chewed for its psychoactive effects, derived from the Catha edulis plant",\n\t\t\t\t"psilocybin mushrooms - a type of mushroom containing the psychedelic compound psilocybin"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 80 out of 338
# {'code': '03.1.1.0', 'title': 'Clothing materials', 'description': '* clothing materials of natural, synthetic and mixed fibres \n* leather, fur, fusible webbing, wadding and felt filling for making wearing apparel'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"clothing materials of natural fibres",\n\t\t\t\t"clothing materials of synthetic fibres",\n\t\t\t\t"clothing materials of mixed fibres",\n\t\t\t\t"leather for making wearing apparel",\n\t\t\t\t"fur for making wearing apparel",\n\t\t\t\t"fusible webbing for making wearing apparel",\n\t\t\t\t"wadding for making wearing apparel",\n\t\t\t\t"felt filling for making wearing apparel"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Processing item 81 out of 338
# Error processing item 97 out of 338
# {'code': '04.2.2.0', 'title': 'Other imputed rentals', 'description': '* imputed rentals for secondary residences \n* imputed garage rentals in connection with the dwelling \n* imputed rentals of storage units'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"imputed rentals for secondary residences",\n\t\t\t\t"imputed garage rentals in connection with the dwelling",\n\t\t\t\t"imputed rentals of storage units"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 98 out of 338
# {'code': '04.3.1.1', 'title': 'Materials for the maintenance and repair of the dwelling', 'description': '* products and materials such as paints and varnishes, renderings, wallpapers, fabric wall coverings, windowpanes, plaster, cement, putty, wallpaper pastes and so on, purchased for minor maintenance and repair of dwellings \n* small plumbing items (pipes, taps, joints, etc.), surfacing materials (floorboards, ceramic tiles, etc.) and brushes and scrapers for paint, varnish and wallpaper \n* fitted carpets and linoleum \n* door fittings, power sockets and wiring flex'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool\\_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"paints and varnishes for minor maintenance of dwellings",\n\t\t\t\t"wallpapers and fabric wall coverings for dwelling repair",\n\t\t\t\t"windowpanes, plaster, cement, putty, and wallpaper pastes for dwelling upkeep",\n\t\t\t\t"small plumbing items such as pipes, taps, and joints for dwelling maintenance",\n\t\t\t\t"surfacing materials like floorboards and ceramic tiles for repairing dwellings",\n\t\t\t\t"brushes and scrapers for paint, varnish, and wallpaper used in dwellings",\n\t\t\t\t"fitted carpets and linoleum for dwellings",\n\t\t\t\t"door fittings, power sockets, and wiring flex for the maintenance and repair of the dwelling"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 99 out of 338
# {'code': '04.3.1.2', 'title': 'Security equipment', 'description': '* small surveillance and security equipment for individual dwellings (smoke detectors, security alarms, and security and surveillance cameras) \n* door phones for dwellings \n* fire extinguishers'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"small surveillance and security equipment for individual dwellings, such as smoke detectors, security alarms, and security and surveillance cameras",\n\t\t\t\t"door phones for dwellings",\n\t\t\t\t"fire extinguishers"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Processing item 101 out of 338
# Error processing item 101 out of 338
# {'code': '04.4.1.1', 'title': 'Water supply delivered through network systems', 'description': '* all charges usually included in the bills paid by households, including meter installation charges and rentals, and volumetric or fixed charges for consumption of water delivered through mains, except for steam and hot water \n * associated expenditures, such as meter rentals, cost of meter readings, standing charges and so on'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"Water supply delivered through network systems, all charges usually included in the bills paid by households, including meter installation charges and rentals, and volumetric or fixed charges for consumption of water delivered through mains, except for steam and hot water",\n\t\t\t\t"Associated expenditures such as meter rentals, cost of meter readings, standing charges and so on"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 102 out of 338
# {'code': '04.4.1.2', 'title': 'Water supply delivered through other systems', 'description': '* payment for services provided at a public standpost or fountain and by water vendors (e.g., via tanker truck or cart)'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"Payment for services provided at a public standpost or fountain",\n\t\t\t\t"Payment for water provided by vendors via tanker truck",\n\t\t\t\t"Payment for water provided by vendors via cart"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 105 out of 338
# ...
# Error processing item 319 out of 338
# {'code': '14.6.3.0', 'title': 'Environmental protection', 'description': 'The same function is covered under COPNI classes 08.1.0 and 08.2.0.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"Environmental protection function that falls under COPNI class 08.1.0",\n\t\t\t\t"Function for environmental protection classified under COPNI class 08.2.0"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 320 out of 338
# {'code': '14.6.4.0', 'title': 'Services n.e.c.', 'description': 'The same function is covered under COPNI classes 09.1.0 and 09.2.0.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"Service not elsewhere classified. This function is covered under COPNI classes 09.1.0 and 09.2.0."\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Processing item 321 out of 338
# Error processing item 321 out of 338
# {'code': '15.1.0.0', 'title': 'Housing', 'description': 'The same function is covered under COFOG class 10.6.0.  \nThis subclass corresponds to COICOP classes 04.1.1 and 14.1.0.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"Housing, covered under COFOG class 10.6.0, corresponds to COICOP classes 04.1.1 and 14.1.0."\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 322 out of 338
# {'code': '15.2.1.0', 'title': 'Pharmaceutical products', 'description': 'The same function is covered under COFOG class 07.1.1.  \nThis subclass corresponds to COICOP classes 06.1.1 and 14.2.1.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"Pharmaceutical products falling under COFOG class 07.1.1",\n\t\t\t\t"COFOG class 07.1.1 covers the same function as COICOP class 06.1.1",\n\t\t\t\t"COFOG class 07.1.1 also corresponds to COICOP class 14.2.1"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 323 out of 338
# {'code': '15.2.2.0', 'title': 'Other medical products', 'description': 'The same function is covered under COFOG class 07.1.2.  \nThis subclass corresponds to COICOP classes 06.1.2 and 14.2.2.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"Medical product for the same function as COFOG class 07.1.2",\n\t\t\t\t"Item corresponding to COICOP class 06.1.2",\n\t\t\t\t"Item corresponding to COICOP class 14.2.2"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 324 out of 338
# {'code': '15.2.3.0', 'title': 'Therapeutic appliances and equipment', 'description': 'The same function is covered under COFOG class 07.1.3.  \nThis subclass corresponds to COICOP classes 06.1.3 and 14.2.3.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"Therapeutic appliance for COFOG class 07.1.3: e.g. crutches, wheelchairs, hearing aids, etc.",\n\t\t\t\t"COFOG class 07.1.3 function examples: provision, maintenance, and repair of therapeutic appliances and equipment",\n\t\t\t\t"COICOP class 06.1.3 items: e.g. medical devices, bandages, and other medical supplies for personal use",\n\t\t\t\t"COICOP class 14.2.3 items: e.g. prosthetic limbs, orthopedic shoes, and other assistive devices for mobility"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 325 out of 338
# {'code': '15.2.4.0', 'title': 'Outpatient medical services', 'description': 'The same function is covered under COFOG classes 07.2.1 and 07.2.2.  \nThis subclass corresponds to COICOP classes 06.2.1, 06.2.3 and 14.2.4.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"Outpatient medical services covered under COFOG classes 07.2.1 and 07.2.2",\n\t\t\t\t"Services corresponding to COICOP classes 06.2.1, 06.2.3, and 14.2.4"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 326 out of 338
# {'code': '15.2.5.0', 'title': 'Outpatient dental services', 'description': 'The same function is covered under COFOG class 07.2.3.  \nThis subclass corresponds to COICOP classes 06.2.2 and 14.2.5.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"Outpatient dental services - COFOG class 07.2.3 - COICOP class 06.2.2",\n\t\t\t\t"Outpatient dental services - COFOG class 07.2.3 - COICOP class 14.2.5"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 327 out of 338
# {'code': '15.2.6.0', 'title': 'Outpatient paramedical services', 'description': 'The same function is covered under COFOG class 07.2.4.  \nThis subclass corresponds to COICOP classes 06.1.4, 06.2.1, 06.2.3, 06.4 and 14.2.6.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"Outpatient paramedical services - COFOG class 07.2.4",\n\t\t\t\t"COFOG class 07.2.4 covers the same function as outpatient paramedical services",\n\t\t\t\t"Outpatient paramedical services correspond to COICOP classes 06.1.4, 06.2.1, 06.2.3, 06.4, and 14.2.6"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 328 out of 338
# {'code': '15.2.7.0', 'title': 'Hospital services', 'description': 'The same function is covered under COFOG classes 07.3.1, 07.3.2, 07.3.3 and 07.3.4.  \nThis subclass corresponds to COICOP group 06.3 and class 14.2.7.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"Hospital services covered under COFOG classes 07.3.1: emergency services, outpatient services, inpatient services",\n\t\t\t\t"Hospital services covered under COFOG classes 07.3.2: specialized medical services, specialized surgical services",\n\t\t\t\t"Hospital services covered under COFOG classes 07.3.3: diagnostic services, therapeutic services",\n\t\t\t\t"Hospital services covered under COFOG classes 07.3.4: rehabilitative services, palliative services",\n\t\t\t\t"Items in this subclass correspond to COICOP group 06.3 and class 14.2.7: medical supplies, pharmaceutical products"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 329 out of 338
# {'code': '15.2.8.0', 'title': 'Public health services', 'description': 'The same function is covered under COFOG class 07.4.0.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool\\_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"Public health services, covered under COFOG class 07.4.0"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 331 out of 338
# {'code': '15.3.2.0', 'title': 'Cultural services', 'description': 'The same function is covered under COFOG class 08.2.0.  \nThis subclass corresponds to COICOP group 09.6 and class 14.3.2.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"Cultural service under COFOG class 08.2.0",\n\t\t\t\t"Corresponds to COICOP group 09.6",\n\t\t\t\t"Classification 14.3.2"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 333 out of 338
# {'code': '15.4.2.0', 'title': 'Secondary education', 'description': 'The same function is covered under COFOG classes 09.2.1 and 09.2.2.  \nThis subclass corresponds to COICOP classes 10.2.0 and 14.4.2.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"Secondary education covered under COFOG classes 09.2.1 and 09.2.2",\n\t\t\t\t"This subclass corresponds to COICOP classes 10.2.0 and 14.4.2"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 334 out of 338
# {'code': '15.4.3.0', 'title': 'Post-secondary non-tertiary education', 'description': 'The same function is covered under COFOG class 09.3.0.  \nThis subclass corresponds to COICOP classes 10.3.0 and 14.4.3.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"Post-secondary non-tertiary education",\n\t\t\t\t"COFOG class 09.3.0",\n\t\t\t\t"COICOP class 10.3.0",\n\t\t\t\t"COICOP class 14.4.3"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 335 out of 338
# {'code': '15.4.4.0', 'title': 'Tertiary education', 'description': 'The same function is covered under COFOG classes 09.4.1 and 09.4.2.  \nThis subclass corresponds to COICOP classes 10.4.0 and 14.4.4.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"Tertiary education",\n\t\t\t\t"The same function is covered under COFOG classes 09.4.1 and 09.4.2",\n\t\t\t\t"This subclass corresponds to COICOP classes 10.4.0 and 14.4.4"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 336 out of 338
# {'code': '15.4.5.0', 'title': 'Education not defined by level', 'description': 'The same function is covered under COFOG class 09.5.0.  \nThis subclass corresponds to COICOP classes 10.5.0 and 14.4.5.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool\\_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"Education not defined by level - COFOG class 09.5.0",\n\t\t\t\t"COICOP class 10.5.0 - Tuition fees",\n\t\t\t\t"COICOP class 14.4.5 - Books and stationery"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 337 out of 338
# {'code': '15.4.6.0', 'title': 'Subsidiary services to education', 'description': 'The same function is covered under COFOG class 09.6.0.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"Subsidiary services to education, covered under COFOG class 09.6.0"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}
# Error processing item 338 out of 338
# {'code': '15.5.0.0', 'title': 'Social protection', 'description': 'The same function is covered under COFOG classes 10.1.1 to 10.5.0 and 10.7.0.  \nThis subclass corresponds to COICOP classes 13.3.0 and 14.5.0.'}
# Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<tool-use>\n{\n\t"tool\\_call": {\n\t\t"id": "pending",\n\t\t"type": "function",\n\t\t"function": {\n\t\t\t"name": "final\\_result"\n\t\t},\n\t\t"parameters": {\n\t\t\t"examples": [\n\t\t\t\t"Social protection function, covered under COFOG classes 10.1.1 to 10.5.0 and 10.7.0",\n\t\t\t\t"Corresponds to COICOP classes 13.3.0 and 14.5.0"\n\t\t\t]\n\t\t}\n\t}\n}\n</tool-use>'}}

# %%
results_df = pd.DataFrame(results)
results_df.drop(columns=["description"]).to_csv(
    "results/coicop2018_{}_{}.csv".format(
        llm_model,
        datetime.now().strftime("%Y-%m-%d_%H%M%S")),
    index=False)

# %%
failed_df = pd.DataFrame(failed_calls)
failed_df.to_csv(
    "results/failed_coicop2018_{}_{}.csv".format(
        llm_model,
        datetime.now().strftime("%Y-%m-%d_%H%M%S")),
    index=False)

# %% [markdown]
# # Combine results

# %%
result_files = [f for f in os.listdir("results/") if f.startswith("coicop2018") and f.endswith(".csv")]

# %%
results_list = []
for f in result_files:
    temp_df = pd.read_csv(os.path.join("results", f))
    results_list.append(temp_df)

results_df = pd.concat(results_list)

# %%
results_df["code"].nunique()
# Out:
# 338

# %% [markdown]
# Normalize to lowercase and remove all "other" labels

# %%
# Lowercase
results_df["title"] = results_df["title"].str.lower()
# Remove duplicates
results_df = results_df.drop_duplicates(ignore_index=True)
# Remove items with "other" or "miscellaneous"
results_df = results_df[~results_df["title"].str.contains("other|miscellaneous")]

# %%
results_df["code"].nunique()
# Out:
# 337

# %%
results_df.to_csv(
    "results/consolidated_coicop2018_20250210.csv", index=False)
